# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1nMaBQ7g88duMECw_B4mH8ruxwnIwVzGP" width=300/>
#
# # ML-1: Exploratory Data Analysis, Visualisation & Modeling
# ## Homework 1: Who is the best singer ever?
#
# **ML-1 Cohort 1** <br>
# **Instructor: Dr. Rahul Dave**<br>
# **Max Score: 100** <br>

# %% [markdown]
# Name of people who have worked on this homework:
#
# ### Gunaseelan Dhanarajan
#
# ### Pavan Kumar

# %% [markdown]
# ## Table of Contents
# * [HW-1: Who is the best singer ever?](#HW-1:-Who-is-the-best-singer-ever?)
#   * [Instructions](##Instructions)
#   * [Learning Goals](##Learning-Goals)
#   * [Q1: Scrape and Parse Wikipedia for Billboard Top 100](##Q1:-Scrape-and-Parse-Wikipedia-for-Billboard-Top-100)
#     * [1.1 Scrape and Parse the Billboard Wikipedia's page for 1970](###1.1-Scrape-and-Parse-the-Billboard-Wikipedia's-page-for-1970)
#     * [1.2 Scrape Billboard Wikipedia's pages from 1992 to 2020](###1.2-Scrape-Billboard-Wikipedia's-pages-from-1992-to-2020)
#     * [1.3 Parse the data](###1.3-Parse-the-data)
#   * [Q2: Construct a year-song-singer dataframe](##Q2:-Construct-a-year-song-singer-dataframe)
#   * [Q3: Scrape and Parse Wikipedia for Information about Artists and Bands](##Q3:-Scrape-and-Parse-Wikipedia-for-Information-about-Artists-and-Bands)
#     * [3.1 Scrape the artist's Wikipedia webpages](###3.1-Scrape-the-artist's-Wikipedia-webpages)
#     * [3.2 Parse the data](###3.2-Parse-the-data)
#   * [Q4: Merging Artist's and Song dataframes](##Q4:-Merging-Artist's-and-Song-dataframes)
#   * [Q5: Pandas and Relational databases](##Q5:-Pandas-and-Relational-databases)
#     * [5.1 Populating the database](###5.1-Populating-the-database)
#     * [5.2 Performing operations on the database](####5.2-Performing-operations-on-the-database)
#       * [5.2.1 Select all singers below the age of 20 whos Zodiac Sign is Scorpio!](####5.2.1-Select-all-singers-below-the-age-of-20-whos-Zodiac-Sign-is-Scorpio!)
#       * [5.2.2 Find the most popular artists with most appearances in Billboard Top 10](####5.2.2-Find-the-most-popular-artists-with-most-appearances-in-Billboard-Top-10)
#       * [5.2.3 Select all songs with ranking less than 6 and order the rows by artist name](####5.2.3-Select-all-songs-with-ranking-less-than-6-and-order-the-rows-by-artist-name)

# %% [markdown]
# ## Instructions

# %% [markdown]
# - This homework should be submitted in pairs.
#
# - Ensure you and your partner together have submitted the homework only once. Multiple submissions of the same work will be penalised and will cost you 2 points.
#
# - Please restart the kernel and run the entire notebook again before you submit.
#
# - Running cells out of order is a common pitfall in Notebooks. To make sure your code works restart the kernel and run the whole notebook again before you submit.
#
# - To work on the homework, you will first need to fork the repository into your GitHub account and clone it to work on it on your local computer. To submit your homework, push your homework into the same GitHub and upload the link on edStem.
#
# - Submit the homework well before the given deadline. Submissions after the deadline will not be graded.
#
# - We have tried to include all the libraries you may need to do the assignment in the imports statement at the top of this notebook. We strongly suggest that you use those and not others as we may not be familiar with them.
#
# - Comment your code well. This would help the graders in case there is any issue with the notebook while running. It is important to remember that the graders will not troubleshoot your code.
#
# - Please use .head() when viewing data. Do not submit a notebook that is **excessively long**.
#
# - In questions that require code to answer, such as "calculate the $R^2$", do not just output the value from a cell. Write a `print()` function that includes a reference to the calculated value, **not hardcoded**. For example:
# ```
# print(f'The R^2 is {R:.4f}')
# ```
# - Your plots should include clear labels for the $x$ and $y$ axes as well as a descriptive title ("MSE plot" is not a descriptive title; "95 % confidence interval of coefficients of polynomial degree 5" is).
#
# - **Ensure you make appropriate plots for all the questions it is applicable to, regardless of it being explicitly asked for.**
#
# <hr style="height:2pt">

# %% [markdown]
# ## Learning Goals

# %% [markdown]
# Billboard Magazine puts out a top 100 list of "singles" every **year**.
# In the next two homeworks, you will scrape Wikipedia to try to understand how the public's taste in music has evolved. You will do this by learning about the best singers and groups from each year as determined by the Billboard top 100 charts.
#
# This homework consists of five main parts:
#
# 1. Scraping and Parsing [Wikipedia's Billboard Top 100 singles](https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2020) list for every year <br>
# 2. Constructing a year-song-singer dataframe from the scraped data
# 3. Scraping and Parsing Wikipedia's information about the Artists from these Songs
# 4. Merging in both the above dataframes
# 5. Using a Relational Database to perform SQL queries

# %% [markdown]
# This homework will help develop your skills in:
#
# - Web page scraping
# - Data cleaning and manipulation
# - Pandas and SQL

# %% [markdown]
# ---

# %%
#Import libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import json
import re
import requests
from bs4 import BeautifulSoup
import bs4

# %% [markdown]
# ## Q1: Scrape and Parse Wikipedia for Billboard Top 100
# #### [20 Points]

# %% [markdown]
# In this first question you will scrape wikipedia for Billboard's top 100.
#
# We will be using [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/) to transform HTML content into Python data structures. There are other libraries such as [PyQuery](https://pythonhosted.org/pyquery/) (for people who have used [jQuery](https://jquery.com/) that can also be used).

# %% [markdown]
# ### 1.1 Scrape and Parse the Billboard Wikipedia's page for 1970

# %% [markdown]
# Use python's `requests` module to obtain (GET) the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970.
# From this web page, extract the top 100 singles and their rankings.
#
#
# To do this, create a list of dictionaries, 100 of them to be precise, with the following entries: `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`.
#
# Name this list of dictionaries `songs`.
#
#
# Here, `url` should be the link for the singer or band (observe that on the web page, there is a link for every song and artist), `ranking` is the ranking of the song, `band_singer` should be the name of the artist(s) and `title` should be the title of the song.
#
#
# We are extracting the `url` of the artist(s) to use at a later stage in the homework.

# %% [markdown]
# *Hint:*
# While parsing the HTML, look for the HTML _tr_ (table row) element, but only the one that has a CSS class of _wikitable_. If you look at the page source, you'll see a construct like __class=wikitable__ on the table as seen below:
#
#
#
# ![Wikipage](
# https://drive.google.com/uc?export=view&id=1ntewsqyZVH6_RETloTQgrWIyQJAa_02D)

# %%
#Get the webpage
t1970 = requests.get("http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970")
#Parsing the webpage
page = t1970.text

# %%
#Parsing the webpage with BeautifulSoup - html parser
soup = BeautifulSoup(page, 'html.parser')
soup.title
# Out:
# <title>Billboard Year-End Hot 100 singles of 1970 - Wikipedia</title>

# %%
#Finding table with wikitable class
tables_wikitable = soup.find_all("table", "wikitable")
print(tables_wikitable)
# Out:
# [<table class="wikitable sortable" style="text-align: center">
# <tbody><tr>
# <th scope="col" style="background:#dde;">No.
# </th>
# <th scope="col" style="background:#dde;">Title
# </th>
# <th scope="col" style="background:#dde;">Artist(s)
# </th></tr>
# <tr>
# <td>1</td>
# <td>"<a class="mw-redirect" href="/wiki/Bridge_Over_Troubled_Water_(song)" title="Bridge Over Troubled Water (song)">Bridge Over Troubled Water</a>"</td>
# <td><a href="/wiki/Simon_%26_Garfunkel" title="Simon &amp; Garfunkel">Simon &amp; Garfunkel</a>
# </td></tr>
# <tr>
# <td>2</td>
# <td>"<a href="/wiki/(They_Long_to_Be)_Close_to_You" title="(They Long to Be) Close to You">(They Long to Be) Close to You</a>"</td>
# <td><a href="/wiki/The_Carpenters" title="The Carpenters">The Carpenters</a>
# </td></tr>
# <tr>
# <td>3</td>
# <td>"<a href="/wiki/American_Woman" title="American Woman">American Woman</a>"</td>
# <td><a href="/wiki/The_Guess_Who" title="The Guess Who">The Guess Who</a>
# </td></tr>
# <tr>
# <td>4</td>
# <td>"<a href="/wiki/Raindrops_Keep_Fallin%27_on_My_Head" title="Raindrops Keep Fallin' on My Head">Raindrops Keep Fallin' on My Head</a>"</td>
# <td><a class="mw-redirect" href="/wiki/B.J._Thomas" title="B.J. Thomas">B.J. Thomas</a>
# </td></tr>
# <tr>
# <td>5</td>
# <td>"<a href="/wiki/War_(The_Temptations_song)#Edwin_Starr_version" title="War (The Temptations song)">War</a>"</td>
# <td><a href="/wiki/Edwin_Starr" title="Edwin Starr">Edwin Starr</a>
# </td></tr>
# <tr>
# <td>6</td>
# <td>"<a href="/wiki/Ain%27t_No_Mountain_High_Enough" title="Ain't No Mountain High Enough">Ain't No Mountain High Enough</a>"</td>
# <td><a href="/wiki/Diana_Ross" title="Diana Ross">Diana Ross</a>
# </td></tr>
# <tr>
# <td>7</td>
# <td>"<a class="mw-redirect" href="/wiki/I%27ll_Be_There_(The_Jackson_5_song)" title="I'll Be There (The Jackson 5 song)">I'll Be There</a>"</td>
# <td><a href="/wiki/The_Jackson_5" title="The Jackson 5">The Jackson 5</a>
# </td></tr>
# <tr>
# <td>8</td>
# <td>"<a href="/wiki/Get_Ready_(The_Temptations_song)#Rare_Earth_version" title="Get Ready (The Temptations song)">Get Ready</a>"</td>
# <td><a href="/wiki/Rare_Earth_(band)" title="Rare Earth (band)">Rare Earth</a>
# </td></tr>
# <tr>
# <td>9</td>
# <td>"<a href="/wiki/Let_It_Be_(Beatles_song)" title="Let It Be (Beatles song)">Let It Be</a>"</td>
# <td><a href="/wiki/The_Beatles" title="The Beatles">The Beatles</a>
# </td></tr>
# <tr>
# <td>10</td>
# <td>"<a href="/wiki/Band_of_Gold_(Freda_Payne_song)" title="Band of Gold (Freda Payne song)">Band of Gold</a>"</td>
# <td><a href="/wiki/Freda_Payne" title="Freda Payne">Freda Payne</a>
# </td></tr>
# <tr>
# <td>11</td>
# <td>"<a href="/wiki/Mama_Told_Me_Not_to_Come" title="Mama Told Me Not to Come">Mama Told Me (Not to Come)</a>"</td>
# <td><a href="/wiki/Pacific_Gas_%26_Electric_(band)" title="Pacific Gas &amp; Electric (band)">Pacific Gas &amp; Electric</a>
# </td></tr>
# <tr>
# <td>94</td>
# <td>"<a href="/wiki/Woodstock_(song)" title="Woodstock (song)">Woodstock</a>"</td>
# <td><a href="/wiki/Crosby,_Stills,_Nash_%26_Young" title="Crosby, Stills, Nash &amp; Young">Crosby, Stills, Nash &amp; Young</a>
# </td></tr>
# <tr>
# <td>95</td>
# <td>"<a href="/wiki/I%27ll_Never_Fall_in_Love_Again" title="I'll Never Fall in Love Again">I'll Never Fall in Love Again</a>"</td>
# <td><a href="/wiki/Dionne_Warwick" title="Dionne Warwick">Dionne Warwick</a>
# </td></tr>
# <tr>
# <td>96</td>
# <td>"<a class="mw-redirect" href="/wiki/Look_What_They%27ve_Done_to_My_Song_Ma" title="Look What They've Done to My Song Ma">Look What They've Done to My Song Ma</a>"</td>
# <td><a href="/wiki/The_New_Seekers" title="The New Seekers">The New Seekers</a>
# </td></tr>
# <tr>
# <td>97</td>
# <td>"<a class="mw-redirect" href="/wiki/Walk_A_Mile_In_My_Shoes" title="Walk A Mile In My Shoes">Walk A Mile In My Shoes</a>"</td>
# <td><a href="/wiki/Joe_South" title="Joe South">Joe South</a>
# </td></tr>
# <tr>
# <td>98</td>
# <td>"<a class="mw-redirect" href="/wiki/The_Thrill_Is_Gone_(1951_song)" title="The Thrill Is Gone (1951 song)">The Thrill Is Gone</a>"</td>
# <td><a href="/wiki/B.B._King" title="B.B. King">B.B. King</a>
# </td></tr>
# <tr>
# <td>99</td>
# <td>"<a href="/wiki/It%27s_Only_Make_Believe" title="It's Only Make Believe">It's Only Make Believe</a>"</td>
# <td><a href="/wiki/Glen_Campbell" title="Glen Campbell">Glen Campbell</a>
# </td></tr>
# <tr>
# <td>100</td>
# <td>"<a href="/wiki/Call_Me_(Aretha_Franklin_song)" title="Call Me (Aretha Franklin song)">Call Me</a>"</td>
# <td><a href="/wiki/Aretha_Franklin" title="Aretha Franklin">Aretha Franklin</a>
# </td></tr>
# </tbody></table>]

# %%
# 1 table with wikitable class found
print(len(tables_wikitable))
# Out:
# 1

# %%
#Printing all the rows <tr> inside table with class wikitable
rows = [row for row in tables_wikitable[0].find_all("tr")]
print(rows)
# Out:
# [<tr>
# <th scope="col" style="background:#dde;">No.
# </th>
# <th scope="col" style="background:#dde;">Title
# </th>
# <th scope="col" style="background:#dde;">Artist(s)
# </th></tr>, <tr>
# <td>1</td>
# <td>"<a class="mw-redirect" href="/wiki/Bridge_Over_Troubled_Water_(song)" title="Bridge Over Troubled Water (song)">Bridge Over Troubled Water</a>"</td>
# <td><a href="/wiki/Simon_%26_Garfunkel" title="Simon &amp; Garfunkel">Simon &amp; Garfunkel</a>
# </td></tr>, <tr>
# <td>2</td>
# <td>"<a href="/wiki/(They_Long_to_Be)_Close_to_You" title="(They Long to Be) Close to You">(They Long to Be) Close to You</a>"</td>
# <td><a href="/wiki/The_Carpenters" title="The Carpenters">The Carpenters</a>
# </td></tr>, <tr>
# <td>3</td>
# </td></tr>, <tr>
# <td>97</td>
# <td>"<a class="mw-redirect" href="/wiki/Walk_A_Mile_In_My_Shoes" title="Walk A Mile In My Shoes">Walk A Mile In My Shoes</a>"</td>
# <td><a href="/wiki/Joe_South" title="Joe South">Joe South</a>
# </td></tr>, <tr>
# <td>98</td>
# <td>"<a class="mw-redirect" href="/wiki/The_Thrill_Is_Gone_(1951_song)" title="The Thrill Is Gone (1951 song)">The Thrill Is Gone</a>"</td>
# <td><a href="/wiki/B.B._King" title="B.B. King">B.B. King</a>
# </td></tr>, <tr>
# <td>99</td>
# <td>"<a href="/wiki/It%27s_Only_Make_Believe" title="It's Only Make Believe">It's Only Make Believe</a>"</td>
# <td><a href="/wiki/Glen_Campbell" title="Glen Campbell">Glen Campbell</a>
# </td></tr>, <tr>
# <td>100</td>
# <td>"<a href="/wiki/Call_Me_(Aretha_Franklin_song)" title="Call Me (Aretha Franklin song)">Call Me</a>"</td>
# <td><a href="/wiki/Aretha_Franklin" title="Aretha Franklin">Aretha Franklin</a>
# </td></tr>]

# %%
#First row is header row
header_row = rows[0]
print(header_row)
# Out:
# <tr>
# <th scope="col" style="background:#dde;">No.
# </th>
# <th scope="col" style="background:#dde;">Title
# </th>
# <th scope="col" style="background:#dde;">Artist(s)
# </th></tr>

# %%
#Printing the column headers names
header_columns = [col.get_text().strip() for col in header_row.find_all("th") if col.get_text()]
print(header_columns)
# Out:
# ['No.', 'Title', 'Artist(s)']

# %%
#Loop through all the rows inside table with class wikitable and extract the following information 
#(ranking, song, song url, band singer and band singer url). Add this info to a dictionary and append dictionary to a list.  
songs = []
for row in rows[1:]:
    songs_dict = {}
    i = 0;
    for value in row.find_all("td"):
        if i == 0:
            songs_dict['Ranking'] = value.text.strip()
        elif i == 1:
            for link in value.findAll('a'):  
                songs_dict['Song'] = link.text.strip()
                songs_dict['Song_URL'] = link.get('href').strip()
        elif i == 2:
             for link in value.findAll('a'):
                 songs_dict['band_singer'] = link.text.strip()
                 songs_dict['URL'] = link.get('href').strip()
        i = i + 1;
    songs.append(songs_dict)

# %%
#Printing the song list
print(songs)
# Out:
# [{'Ranking': '1', 'Song': 'Bridge Over Troubled Water', 'Song_URL': '/wiki/Bridge_Over_Troubled_Water_(song)', 'band_singer': 'Simon & Garfunkel', 'URL': '/wiki/Simon_%26_Garfunkel'}, {'Ranking': '2', 'Song': '(They Long to Be) Close to You', 'Song_URL': '/wiki/(They_Long_to_Be)_Close_to_You', 'band_singer': 'The Carpenters', 'URL': '/wiki/The_Carpenters'}, {'Ranking': '3', 'Song': 'American Woman', 'Song_URL': '/wiki/American_Woman', 'band_singer': 'The Guess Who', 'URL': '/wiki/The_Guess_Who'}, {'Ranking': '4', 'Song': "Raindrops Keep Fallin' on My Head", 'Song_URL': '/wiki/Raindrops_Keep_Fallin%27_on_My_Head', 'band_singer': 'B.J. Thomas', 'URL': '/wiki/B.J._Thomas'}, {'Ranking': '5', 'Song': 'War', 'Song_URL': '/wiki/War_(The_Temptations_song)#Edwin_Star
singer': 'Five Stairsteps', 'URL': '/wiki/Five_Stairsteps'}, {'Ranking': '22', 'Song': 'Spirit in the Sky', 'Song_URL': '/wiki/Spirit_in_the_Sky', 'band_singer': 'Norman Greenbaum', 'URL': '/wiki/Norman_Greenbaum'}, {'Ranking': '23', 'Song': 'Lay Down (Candles in the Rain)', 'Song_URL': '/wiki/Lay_Down_(Candles_in_the_Rain)', 'band_singer': 'Melanie', 'URL': '/wiki/Melanie_Safka'}, {'Ranking': '24', 'Song': "Ball of Confusion (That's What the World Is Today)", 'Song_URL': '/wiki/Ball_of_Confusion_(That%27s_What_the_World_Is_Today)', 'band_singer': 'The Temptations', 'URL': '/wiki/The_Temptations'}, {'Ranking': '25', 'Song': 'Love on a Two-Way Street', 'Song_URL': '/wiki/Love_on_a_Two-Way_Street', 'band_singer': 'The Moments ...

# %% [markdown]
# ### 1.2 Scrape Billboard Wikipedia's pages from 1992 to 2020

# %% [markdown]
# By visiting urls similar to the one for 1970, we can obtain the billboard top 100 for the years 1992 to 2020.
#
# Store the text from your `requests` in a dictionary called `yearstext`.
# This dictionary should have as its keys the years (as integers from 1992 to 2020). The values corresponding to these keys should be the html text downloaded from Wikipedia.<br>
# So, each entry in `yearstext` will look something like this:
#
# ![yearstext](https://drive.google.com/uc?export=view&id=16LNIyznVnAY-N5EN6lsSB9505fXG1-zK)
#
# where the key is 1992 and the value is the HTML at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1992.

# %% [markdown]
# *Hint*:
# Put your requests.get() in a `for` loop and keep appending the text from your requests into the dictionary. Use the `time.sleep` function to wait one second between requests, you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %%
#generate list of urls 
urls = ['http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_{0}'.format(str(i)) for i in range(1992, 2021)]
def get_text(urls):
    yearstext = {}
    for url in urls:
        req = requests.get(url)
        yearstext[url.split('_')[-1]] = req.text
        time.sleep(1)
    return yearstext

# %%
print(urls)
# Out:
# ['http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1992', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1993', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1994', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1995', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1996', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1998', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1999', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2000', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2001', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2002', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2003', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2004', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2005', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2006', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2007', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2008', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2009', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2010', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2011', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2012', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2013', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2014', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2015', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2016', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2017', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2018', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2019', 'http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_2020']

# %%
yearstext = get_text(urls)

# %%
#Print and verify the dictionary for any one year
yearstext["2020"]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 2020 - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"YBYK9ApAADoAAHh4JjgAAABN","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_2020","wgTitle":"Billboard Year-End Hot 100 singles of 2020","wgCurRevisionId":1000471086,"wgRevisionId":1000471086,"wgArticleId":66004147,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["2020 record charts","Billboard charts"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Billboard_Year-End_Hot_100_singles_of_2020","wgRelevantArticleId":66004147,"wgIsProbablyEditable":!0,\n"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgPopupsConflictsWithRefTooltipsGadget":!0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q103827484"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready",\n"jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n<meta name="generator" content="MediaWiki 1.36.0-wmf.27"/>\n<meta name="referrer" content="origin"/>\n<meta name="referrer" content="origin-when-crossorigin"/>\n<meta name="referrer" content="origin-when-cross-origin"/>\n<met ...

# %% [markdown]
# ### 1.3 Parse the data

# %% [markdown]
# Now, write a function `parse_year(year, yeartextdict)` that returns a dictionary `yearinfo`.
# Here `year` should be the integer value of the year, and `yeartextdict` should be the HTML text for the corresponding webpage.
# This function should return a dictionary of the following form:
#
# ```
# {'ranking': 32,
#  'song': ['Hot Boyz (song)'],
#  'songurl': ['/wiki/Hot_Boyz_(song)'],
#  'titletext': '"Hot Boyz"',
#  'band_singer': ['Missy Elliott', 'Nas', 'Eve (rapper)', 'Q-Tip (musician)'],
#  'url': ['/wiki/Missy_Elliott',
#   '/wiki/Nas',
#   '/wiki/Eve_(rapper)',
#   '/wiki/Q-Tip_(musician)']}
# ```
# Notice that the `titletext` is the contents of the table cell, and retains the quotes that wikipedia puts on the single.
#
# Here are some issues that you will need to take care of:
#
# 1.   The example shown above has several artists for a single song. In this case, the `band_singer` and `url` would be a list of items.
#
# 2.   Some singles might even have multiple songs because of the way the industry works:
# ```
# {'ranking': 98,
#  'song': ["You're Makin' Me High", 'Let It Flow (song)'],
#  'songurl': ['/wiki/You%27re_Makin%27_Me_High', '/wiki/Let_It_Flow_(song)'],
#  'titletext': '"You\'re Makin\' Me High" / "Let It Flow"',
#  'band_singer': ['Toni Braxton'],
#  'url': ['/wiki/Toni_Braxton']}
# ```
# (See 1997 for an example)
#
# 3. Some songs don't have a URL. In this case, assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped:
# ```
# {'ranking': 45,
#   'song': ['Say It'],
#   'songurl': [None],
#   'titletext': '"Say It"',
#   'band_singer': ['Voices of Theory'],
#   'url': ['/wiki/Voices_of_Theory']}
# ```
# (See 1998 for an example)

# %%
"""
Function
--------
parse_year

Inputs
------
year: the year you want the singles for
ytextdixt: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    
"""
def parse_year(year, ytextdict):
    soup_year = BeautifulSoup(ytextdict[year], 'html.parser')
    tables_wikitable_year = soup_year.find_all("table", "wikitable")
    songs_years = []
    rows_years = [row_year for row_year in tables_wikitable_year[0].find_all("tr")]    
    for row_year in rows_years[1:]:
        songs_years_dict = {}        
        i = 0;
        songs_years_dict['Year'] = year
        for value_year in row_year.find_all("td"):            
            if i == 0:
                songs_years_dict['Ranking'] = value_year.text.strip()
            elif i == 1:
                song_title = []
                song_URL = []
                for link in value_year.findAll('a'):
                    song_title.append(link.text.strip())
                    song_URL.append(link.get('href').strip())                    
                songs_years_dict['Song'] = song_title
                songs_years_dict['Song_URL'] = song_URL
            elif i == 2:
                band_singer = []
                band_singer_URL = []
                for link in value_year.findAll('a'):
                    band_singer.append(link.text.strip())
                    band_singer_URL.append(link.get('href').strip())                    
                songs_years_dict['Band_Singer'] = band_singer
                songs_years_dict['URL'] = band_singer_URL
            i = i + 1;
        songs_years.append(songs_years_dict)
    return songs_years

# %%
def parse_year(year, yeartext_dict):
    soup = BeautifulSoup(yeartext_dict[str(year)], 'html.parser')
    tables_wikitable = soup.find_all('table', 'wikitable')
    rows = [row for row in tables_wikitable[0].find_all('tr')][1:]
    yearinfo = [get_single_dict(year, row) for row in rows]
    return yearinfo
def get_single_dict(year, row):    
    children = [child for child in row.children]
    children = list(filter(lambda x: x != '\n', children))
    ranking = children[0].string
    band_singers = children[2].find_all('a')
    band_singer = [band.string for band in band_singers]
    url = [url['href'] for url in band_singers]
    songs = children[1].find_all('a')
    songurl = [song['href'] for song in songs]
    
    #handles cases where contents are missing
    if songurl == []:
        songurl = [None]
    song = [song.string for song in songs]
    if not song:
        song = children[1].string        
    if type(song) == list:
        title = '/'.join(str(s) for s in song)
    else:
        title = song
    single_dict = {'year': year, 'band_singer': band_singer, 'ranking': ranking, 'song': song, 'songurl':songurl, 'titletext':title, 'url': url}
    return single_dict

# %%
#Call parse_year method for all years (1992-2021) and store the result inside a list
yearinfo = []
iKey = 0
for iYear in range(1992, 2021):
    yearinfo.append(parse_year(iYear, yearstext))
    iKey = iKey + 1

# %% [markdown]
# Save this dictionary as a json file so you do not need to run it over and over again.

# %%
#Store the dictionary and delete the variable
fd = open("yearinfo.json","w")
json.dump(yearinfo, fd)
fd.close()
del yearinfo

# %%
#Load the dictionary back to the same variable
with open("yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %% [markdown]
# ## Q2: Construct a year-song-singer dataframe
# #### [20 points]

# %% [markdown]
# Now, let's construct a dataframe from the dictionary created in the previous section `yearinfo`.
# Name this dataframe `flatframe`.
#
# Keep in mind, in the data structure we have so far, a given key can have a list of values with multiple entries. Also, our data is grouped by year. So we need a way to flatten this data into a format that will create a useful DataFrame.
#
# An easy way to do this is to use the pandas `concat` function.
#
# Your final dataframe `flatframe` should look something like this:
# ![flatframexample](https://drive.google.com/uc?export=view&id=12hlpB-zRGJh6JYCTcMoTzumKSyXgfoiY)

# %%
#Dataframe flatframe should have data for all the years (1992-2021)
flatframe = pd.DataFrame(yearinfo[0])
for iYear in range(len(yearinfo) - 1):
    flatframe1 = pd.DataFrame(yearinfo[iYear])
    flatframe = pd.concat([flatframe, flatframe1], ignore_index=True)

# %%
flatframe.head()
# Out:
#    year         band_singer ranking                      song  \
# 0  1992       [Boyz II Men]       1         [End of the Road]
# 1  1992     [Sir Mix-a-Lot]       2           [Baby Got Back]
# 2  1992        [Kris Kross]       3                    [Jump]
# 3  1992  [Vanessa Williams]       4  [Save the Best for Last]
# 4  1992               [TLC]       5          [Baby-Baby-Baby]
#
#                                       songurl               titletext  \
# 0  [/wiki/End_of_the_Road_(Boyz_II_Men_song)]         End of the Road
# 1                       [/wiki/Baby_Got_Back]           Baby Got Back
# 2              [/wiki/Jump_(Kris_Kross_song)]                    Jump
# 3              [/wiki/Save_the_Best_for_Last]  Save the Best for Last
# 4                      [/wiki/Baby-Baby-Baby]          Baby-Baby-Baby
#
#                            url
# 0          [/wiki/Boyz_II_Men]
# 1        [/wiki/Sir_Mix-a-Lot]
# 2           [/wiki/Kris_Kross]
# 3  [/wiki/Vanessa_L._Williams]
# 4           [/wiki/TLC_(band)]

# %%
#clean dataframe, create new rows for singles with multiple band_singers

cols = ['band_singer', 'song', 'songurl', 'url']
for col in cols:
    flatframe[col] = flatframe[col].apply(lambda x: x[0] if type(x) == list and len(x)==1 else x) 
    
bands_expanded = flatframe.apply(lambda x: pd.Series(x['band_singer']),axis=1).stack().reset_index(level=1, drop=True)
urls_expanded = flatframe.apply(lambda x: pd.Series(x['url']),axis=1).stack().reset_index(level=1, drop=True)
df_bandrows = pd.concat([bands_expanded, urls_expanded], axis = 1)
df_bandrows.columns = ['band_singer', 'url']
flatframe = flatframe.drop(df_bandrows.columns, axis=1).join(df_bandrows)
#clean rankings, strip new line
flatframe.ranking = flatframe.ranking.str.strip('\n')
# Out:
# <ipython-input-23-092f91b6b4c9>:7: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   bands_expanded = flatframe.apply(lambda x: pd.Series(x['band_singer']),axis=1).stack().reset_index(level=1, drop=True)
# <ipython-input-23-092f91b6b4c9>:8: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   urls_expanded = flatframe.apply(lambda x: pd.Series(x['url']),axis=1).stack().reset_index(level=1, drop=True)

# %%
#create new row for singles with multiple songs 

newframe =flatframe[flatframe.song.apply(lambda x: type(x) == list)]
flatframe_dropped = flatframe[flatframe.song.apply(lambda x: type(x) != list)]

songs_expanded = newframe.apply(lambda x: pd.Series(x['song']),axis=1).stack().reset_index(level=1, drop=True)
songurls_expanded = newframe.apply(lambda x: pd.Series(x['songurl']),axis=1).stack().reset_index(level=1, drop=True)


df_expanded = pd.concat([songs_expanded, songurls_expanded], axis = 1)
df_expanded.columns = ['song', 'songurl']

flatframe = flatframe.drop(df_expanded.columns, axis = 1).join(df_expanded, how = 'inner')
flatframe = pd.concat([flatframe_dropped, flatframe], sort = True)
flatframe = flatframe[['ranking', 'band_singer','song', 'songurl', 'titletext', 'url', 'year']]

# %%
flatframe = flatframe[~flatframe.ranking.isna()]

# %%
#handle case of ranking ties
flatframe.loc[:,0] = flatframe.ranking.apply(lambda x: '0' if x == 'Tie' else x)

flatframe = flatframe.astype({'ranking': int, 'url': str})
tied_rankings = flatframe[flatframe.ranking == 0].index
tied_values = [38, 55,86, 92, 92]
for i, tie in enumerate(tied_rankings):
    flatframe.loc[tie, 'ranking' ] = tied_values[i]

# %% [markdown]
# Check your dataframes data types and convert them to the correct data types if needed.

# %%
flatframe.dtypes
# Out:
# ranking         int32
# band_singer    object
# song           object
# songurl        object
# titletext      object
# url            object
# year            int64
# 0              object
# dtype: object

# %%
#Convert to datatypes to required type
flatframe['year'] = flatframe['year'].astype('int')
flatframe['ranking'] = flatframe['ranking'].astype('int')
flatframe['song'] = flatframe['song'].astype('string')
flatframe['songurl'] = flatframe['songurl'].astype('string')
flatframe['band_singer'] = flatframe['band_singer'].astype('string')
flatframe['url'] = flatframe['url'].astype('string')

# %%
flatframe.dtypes
# Out:
# ranking         int32
# band_singer    string
# song           string
# songurl        string
# titletext      object
# url            string
# year            int32
# 0              object
# dtype: object

# %% [markdown]
# We use this dataframe in Homework 2, so store this dataframe so you won't need to run this again!
#
# The easiest way is to pickle it using to_pickle:

# %%
#Store the dataframe and delete the variable
flatframe.to_pickle('flatframedf')
del flatframe

# %%
#Loading in the dataframe
flatframe = pd.read_pickle('flatframedf')
flatframe.head()
# Out:
#    ranking       band_singer                    song  \
# 0        1       Boyz II Men         End of the Road
# 1        2     Sir Mix-a-Lot           Baby Got Back
# 2        3        Kris Kross                    Jump
# 3        4  Vanessa Williams  Save the Best for Last
# 4        5               TLC          Baby-Baby-Baby
#
#                                     songurl               titletext  \
# 0  /wiki/End_of_the_Road_(Boyz_II_Men_song)         End of the Road
# 1                       /wiki/Baby_Got_Back           Baby Got Back
# 2              /wiki/Jump_(Kris_Kross_song)                    Jump
# 3              /wiki/Save_the_Best_for_Last  Save the Best for Last
# 4                      /wiki/Baby-Baby-Baby          Baby-Baby-Baby
#
#                          url  year  0
# 0          /wiki/Boyz_II_Men  1992  1
# 1        /wiki/Sir_Mix-a-Lot  1992  2
# 2           /wiki/Kris_Kross  1992  3
# 3  /wiki/Vanessa_L._Williams  1992  4
# 4           /wiki/TLC_(band)  1992  5

# %% [markdown]
# ## Q3: Scrape and Parse Wikipedia for Information about Artists and Bands
# #### [25 points]

# %% [markdown]
# Now, we need to fetch information about the singers or bands for all the songs in a list of years.

# %% [markdown]
# ### 3.1 Scrape the artist's Wikipedia webpages

# %% [markdown]
# Since we have hundreds of artists webpages to scrape, we have created a function which implements caching in order to speed up this process.
#
# The cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Remember that this function is designed to be used in a loop over years, and then a loop over songs per year. Since network requests are relatively slow, if we have already requested for a singer or band's wikipedia page, caching the results is a smart thing to do.
#
#
#
# Notice that we have wrapped the call in _an exception block_. If the request gets an HTTP code different from 200, the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.

# %%
urlcache={}
def get_page(url):
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)
            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# Before we apply our function to the dataframe, let us sort `flatframe` by year. This will ensure that we will hit the cache most as singers who show up repeatedly in the rankings will have their information already pulled.

# %%
flatframe = flatframe.sort_values('year')
flatframe.head()
# Out:
#      ranking     band_singer                              song  \
# 0          1     Boyz II Men                   End of the Road
# 126       27  Atlantic Starr                       Masterpiece
# 127       28     Celine Dion                If You Asked Me To
# 128       29        En Vogue  Giving Him Something He Can Feel
# 129       30      Joe Public                    Live and Learn
#
#                                       songurl  \
# 0    /wiki/End_of_the_Road_(Boyz_II_Men_song)
# 126   /wiki/Masterpiece_(Atlantic_Starr_song)
# 127                  /wiki/If_You_Asked_Me_To
# 128               /wiki/Something_He_Can_Feel
# 129    /wiki/Live_and_Learn_(Joe_Public_song)
#
#                             titletext                      url  year   0
# 0                     End of the Road        /wiki/Boyz_II_Men  1992   1
# 126                       Masterpiece     /wiki/Atlantic_Starr  1992  27
# 127                If You Asked Me To        /wiki/Celine_Dion  1992  28
# 128  Giving Him Something He Can Feel           /wiki/En_Vogue  1992  29
# 129                    Live and Learn  /wiki/Joe_Public_(band)  1992  30

# %%
# Here we are populating the url cache
#Note that this function will take around 20 minutes to run as we are requestinf for several pages
#This function is designed to be run again and again: it just tries to make sure that there are no unresolved pages left. 
flatframe["url"].apply(get_page)
# Out:
# 0       <!DOCTYPE html>\n<html class="client-nojs" lan...
# 126     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 127     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 128     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 129     <!DOCTYPE html>\n<html class="client-nojs" lan...
#                               ...
# 2843    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2844    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2844    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2846    <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2803    <!DOCTYPE html>\n<html class="client-nojs" lan...
# Name: url, Length: 3873, dtype: object

# %%
#Let us make sure that there are no unresolved pages
#The sum below should be 0, and the boolean True. If that is not the case, run the above cell again until you get a sum of 0 and a boolean True
print (np.sum([(urlcache[k]==1) or (urlcache[k]==2) and isinstance(k,str) for k in urlcache]))
print (len(flatframe.url.unique())==len(urlcache))#we got all of the urls
# Out:
# 1
# True

# %%
#Let's save the `urlcache` and remove the old object. 
keys_values = urlcache.items()
urlcache = {str(key): str(value) for key, value in keys_values}
with open("artistinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %%
with open("artistinfo.json") as json_file:
    urlcache = json.load(json_file)

# %% [markdown]
# ### 3.2 Parse the data

# %% [markdown]
# Now, we need to extract the following information from each page. Write a function `singer_band_info(url, page_text)` that returns a dictionary.
#
# Here `url` should be the path the url corresponding to the singer's Wikipedia page (same as the previous dataframe `flatframe`), and page_text should be the HTML text for the corresponding artist's webpage.
#
# This function should return a dictionary which contains the following information:
#
# 1. The genres of the band or singer. These genres should be urls, to ensure their uniqueness. Create a list, `genres`, of these urls. If there are no genres, use `['NA']`.
#
# 2. If the page has the text "Born", extract the element with the class `.bday`. If there is no "Born", store `False`. Store either of these into the variable `born`.
#
# 3. If the text "Years active" is found, but there is no birthday, assume a band. Store the years active into the variable `ya`, or `False` if the text is not found.
#
# The information can be found below the artists image on each such wikipedia page, as the example here shows:
#
#
# ![EdSheeran](https://drive.google.com/uc?export=view&id=1NJi2C-Gi5HPziuPxefNcjj5i4-04kuQ-)

# %% [markdown]
# The dictionary returned should be of the form:
# ```
# { 'url': '/wiki/Boyz_II_Men',
# 'genres': ['/wiki/Contemporary_R%26B_music', '/wiki/Soul_music', '/wiki/New_jack_swing'],
# 'born': None,
# 'ya': '1987–present'}
# ```
#
# Wikipedia has changed it's format along the years! So observing one artist's webpage and building your function based on it will probably give you tons of errors.
#
# Here are a few issues to remember while parsing:
#
# 1.   There are several artists that take a sabbatical between their active years (https://en.wikipedia.org/wiki/Tony!_Toni!_Ton%C3%A9!). To get the right data, write a function to calculate the longest period of time they were active and consider that as your variable `years active`. In the example give, this would be 2003–present.
# 2.   Birthday's are given in different formats for different pages. For example - https://en.wikipedia.org/wiki/Sir_Mix-a-Lot and https://en.wikipedia.org/wiki/Ed_Sheeran have different formats. To ensure that you get the right day, look for the 'span' tag with a 'bday' tag and ensure that there are no paranthesis around the extracted text.
# 3. Year's active are also given in different formats. For example - https://en.wikipedia.org/wiki/Boyz_II_Men and https://en.wikipedia.org/wiki/Ed_Sheeran are different. You could use regex ("[0-9]{4}[–][0-9]{4}" and "[0-9]{4}[–][0-9]{4}") to ensure you are getting the right years.<br> Report the edge cases found and why the Regex expression takes care of all these edge cases.
#
# Definitely do look at your outputs as you are parsing as it can identify several edge cases you have not considered in your code.

# %% [markdown]
# Before parsing, it is important to note that Wikipedia has defined the same genre in a few different ways. Our parsing code will pick these up as different and new as they all differ with the alphabet case or an underscore instead of a hyphen.
#
# We have defined a function to ensure that we have the correct representation of the number of artists in a particular genre.

# %%
genres_duplicates={'/wiki/Adult_Contemporary_music':'/wiki/Adult_contemporary','/wiki/Adult_contemporary_music':'/wiki/Adult_contemporary',
'/wiki/Afrobeat':'/wiki/Afrobeats',
'/wiki/Alternative_rock':'/wiki/Alternative_Rock',
'/wiki/Avant-garde':'/wiki/Avant-garde_music',
'/wiki/Blues':'/wiki/Blues_music',
'/wiki/Comedy_hip-hop':'/wiki/Comedy_hip_hop',
'/wiki/Contemporary_R%26B':'/wiki/Contemporary_R%26B_music',
'/wiki/Contemporary_folk':'/wiki/Contemporary_folk_music',
'/wiki/Country_Folk':'/wiki/Country_folk',
'/wiki/Dance_pop':'/wiki/Dance-pop',
'/wiki/East_Coast_hip_hop':'/wiki/East_coast_hip_hop',
'/wiki/Electronic_Dance_Music':'/wiki/Electronic_dance_music',
'/wiki/Electronica':'/wiki/Electronica_music',
'/wiki/Emo':'/wiki/Emo_music',
'/wiki/Electropop':'/wiki/Electro-pop',
'/wiki/Folk-pop':'/wiki/Folk_pop',
'/wiki/Funk':'/wiki/Funk_music',
'/wiki/Grime_(music_genre)':'/wiki/Grime_music',
'/wiki/Gangsta_Rap':'/wiki/Gangsta_rap',
'/wiki/Hip_Hop_music': '/wiki/Hip_hop','/wiki/Hip_hop_music':'/wiki/Hip_hop',
'/wiki/Hyphy':'/wiki/Hyphy_music',
'/wiki/Latin_music':'/wiki/Latin_music_(genre)',
'/wiki/West_Coast_hip_hop':'/wiki/West_coast_hip_hop',
'/wiki/Southern_Hip_Hop':'/wiki/Southern_hip_hop',
'/wiki/Ska':'/wiki/Ska_music',
'/wiki/Pop-rock':'/wiki/Pop_rock',
'/wiki/Pop_Music':'/wiki/Pop_music',
'/wiki/Nu_metal':'/wiki/Nu_metal_music'}

def genre_duplicates(genres):
    for i in range(len(genres)):
        if genres[i] in genres_duplicates.keys():
            genres[i]=genres_duplicates[genres[i]]
    return genres

# %% [markdown]
# Define a function to calculate the longest active years

# %%
def longest_Active_years(yearList):
    longest_ay=''
    longest_duration =0
    pairFound = False
    singleFound =False
    singleVal =0
    singleValDur =''
    #print(len(yearList))
    for i in range(len(yearList)):
        temp_duration = yearList[i] 
        temp_count = 0
        #print(yearList[i])
        tupleVal = yearList[i].split('–')
        #print(tupleVal)
        if len(tupleVal) == 2:
            #print(tupleVal[0])
           # print(tupleVal[1])
            pairFound = True
            if tupleVal[1] == 'present':
                temp_count = 2021-int(tupleVal[0])
            else:
                temp_count = int(tupleVal[1]) - int(tupleVal[0])
            
            if longest_duration<temp_count:
                longest_duration = temp_count
                longest_ay = temp_duration
        elif len(tupleVal) == 1:
            #print(tupleVal[0])
            singleFound = True
            if singleVal < int(tupleVal[0]):
                singleVal = int(tupleVal[0])

# %% [markdown]
# Please write the function `singer_band_info` according to the following specification:

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    genres: the genres that the band or singer works in
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""
import re
def singer_band_info(url, page_text):
    born = False
    ya = False
    genres = False
    soup = BeautifulSoup(page_text,'html.parser') 
    table_strings = [th.string for th in soup.find_all('th')]    
    
    #get and clean year born data
    if "Born" in table_strings:
        year_born_td = [tr.td for tr in soup.find_all('tr') if tr.th and tr.th.string == 'Born'][0]
        for child in year_born_td.children:
            span = child.find('span')         
            if type(span) == bs4.element.Tag and span.span:
                born = span.span.string           
            elif type(span) == bs4.element.Tag and span['class'] == ['bday']:
                born = span.string  
    if "Genres" in table_strings:
        genres_td = [tr.td for tr in soup.find_all('tr') if tr.th and tr.th.string == 'Genres'][0]        
        genres = []
        genres_child = ''
        genres_child_url = ''
        if genres_td.findAll('a'):
            for link in genres_td.findAll('a'):  
                genres_child = link.text.strip()
                genres_child_url = link.get('href').strip()
        elif genres_td.findAll('li'):
            for li in genres_td.find_all('li'):
                for link in li.findAll('a'):  
                    genres_child = link.text.strip()
                    genres_child_url = link.get('href').strip()
        else: 
            genres_child = genres_td.text.strip()
        genres.append("Genre: " + genres_child_url)
    if "Years active" in table_strings:
        years_active_td = [tr.td for tr in soup.find_all('tr') if tr.th and tr.th.string == 'Years active'][0]        
        if years_active_td.string:
            ya = years_active_td.string.split("–")       
        elif not years_active_td.find_all('li'):
            ya = [date for date in years_active_td.contents if type(date) == bs4.element.NavigableString]
            #ya = years_active_td.text.strip()            
            #list_of_nums = map(int, re.findall('\d+', ya))
            #print(list_of_nums)
        else:
            ya = []
            for li in years_active_td.find_all('li'):
                for link in li.findAll('a'):  
                    ya_child = link.text.strip()
                    ya_child_url = link.get('href').strip()
                    ya.append("Year Active: " + ya_child)            
            #list_of_nums = map(int, years_active_td.findall('\d+', ya_child))
            #print(list_of_nums)
    #longest_Active_years(ya)
    #for items in ya:
    #print(items)    
    return { "genre" :  genres, "url": url, "born": born, "ya": ya}

# %% [markdown]
# Let's iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a list.
#
# Each element in this list is the dictionary that the function `singer_band_info` returns.
#
# The list should look something like this:
# ```
#   'genres': ['/wiki/Contemporary_R%26B_music',
#    '/wiki/Soul_music',
#    '/wiki/New_jack_swing'],
#   'url': '/wiki/Boyz_II_Men',
#   'ya': '1987–present'},
#  {'born': None,
#   'genres': ['/wiki/Pop_music',
#    '/wiki/Electronica_music',
#    '/wiki/Dance_music',
#    '/wiki/Rave_music',
#    '/wiki/House_music'],
#   'url': '/wiki/KWS_(band)',
#   'ya': '1991–1994'},
#  ... and so on]
#   ```

# %%
band_singer_info_list = []
for key, value in urlcache.items():   
    #band_singer_info_list.append(singer_band_info(key, value))
    band_singer_info_list.append(singer_band_info(key, value))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-88df8d62f463> in <module>
#       2 for key, value in urlcache.items():
#       3     #band_singer_info_list.append(singer_band_info(key, value))
# ----> 4     band_singer_info_list.append(singer_band_info(key, value))
#       5
#
# <ipython-input-60-b54405e057c1> in singer_band_info(url, page_text)
#      37             if type(span) == bs4.element.Tag and span.span:
#      38                 born = span.span.string
# ---> 39             elif type(span) == bs4.element.Tag and span['class'] == ['bday']:
#      40                 born = span.string
#      41     if "Genres" in table_strings:
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1399         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1400         and throws an exception if it's not there."""
# -> 1401         return self.attrs[key]
#    1402
#    1403     def __iter__(self):
#
# KeyError: 'class'

# %%
#temp = singer_band_info("/wiki/Color_Me_Badd", urlcache["/wiki/Color_Me_Badd"])

# %%
band_singer_info_list
# Out:
# [{'url': '/wiki/Boyz_II_Men',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': False,
#   'ya': ['1987–present']},
#  {'url': '/wiki/Atlantic_Starr',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': False,
#   'ya': ['1976', 'present']},
#  {'url': '/wiki/Celine_Dion',
#   'genre': ['Genre: /wiki/Soft_rock'],
#   'born': '1968-03-30',
#   'ya': False},
#  {'url': '/wiki/En_Vogue',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': False,
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Joe_Public_(band)',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': False,
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Jodeci',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': False,
#   'ya': ['1989–present', '(hiatus 1996–2014)']},
#  {'url': '/wiki/Nirvana_(band)',
#   'genre': ['Genre: /wiki/Alternative_rock'],
#   'born': False,
#   'ya': ['1987', '1994']},
#  {'url': '/wiki/Bobby_Brown',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': '1969-02-05',
#   'ya': False},
#  {'url': '/wiki/Sophie_B._Hawkins',
#   'genre': ['Genre: /wiki/Pop_rock'],
#   'born': '1964-11-01',
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Tevin_Campbell',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': '1976-11-12',
#   'ya': ['1988', 'present']},
#  {'url': '/wiki/TLC_(band)',
#   'genre': ['Genre: #cite_note-2'],
#   'born': False,
#   'ya': ['1990–present']},
#  {'url': '/wiki/Elton_John',
#   'genre': ['Genre: /wiki/Soft_rock'],
#   'born': '1947-03-25',
#   'ya': False},
#  {'url': '/wiki/Ya_Kid_K',
#   'genre': ['Genre: /wiki/House_music'],
#   'born': '1972-01-26',
#   'ya': False},
#  {'url': '/wiki/Queen_(band)',
#   'genre': ['Genre: /wiki/Rock_music'],
#   'born': False,
#   'ya': ['1970', 'present']},
#  {'url': '/wiki/Arrested_Development_(group)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1988', '1996, 2000', 'present']},
#  {'url': '/wiki/Luther_Vandross',
#   'genre': ['Genre: /wiki/Post-disco'],
#   'born': '1951-04-20',
#   'ya': ['1969', '2005']},
#  {'url': '/wiki/Janet_Jackson',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': '1966-05-16',
#   'ya': False},
#  {'url': '/wiki/Mariah_Carey',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1969-03-27',
#   'ya': False},
#  {'url': '/wiki/P.M._Dawn',
#   'genre': ['Genre: #cite_note-npr-2'],
#   'born': False,
#   'ya': ['1988', 'present']},
#  {'url': '/wiki/Shakespears_Sister',
#   'genre': ['Genre: /wiki/Gothic_rock'],
#   'born': False,
#   'ya': ['1988', '1996, 2009', '2013, 2019']},
#  {'url': '/wiki/MC_Hammer',
#   'genre': ['Genre: /wiki/Dance_music'],
#   'born': '1962-03-30',
#   'ya': ['1985', 'present']},
#  {'url': '/wiki/Technotronic',
#   'genre': ['Genre: /wiki/Tech_house'],
#   'born': False,
#   'ya': ['1988', '2000']},
#  {'url': '/wiki/George_Michael',
#   'genre': ['Genre: /wiki/Blue-eyed_soul'],
#   'born': '1963-06-25',
#   'ya': False},
#  {'url': '/wiki/The_New_Power_Generation',
#   'genre': ['Genre: /wiki/Psychedelic_music'],
#   'born': False,
#   'ya': ['1990', '2013, 2015, 2017']},
#  {'url': '/wiki/Prince_(entertainer)',
#   'genre': ['Genre: #cite_note-1'],
#   'born': '1958-06-07',
#   'ya': False},
#  {'url': '/wiki/Kris_Kross',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1991', '2001, 2007', '2013']},
#  {'url': '/wiki/Vanessa_L._Williams',
#   'genre': ['Genre: /wiki/Gospel_music'],
#   'born': '1963-03-18',
#   'ya': False},
#  {'url': '/wiki/Eric_Clapton',
#   'genre': ['Genre: /wiki/Blues'],
#   'born': '1945-03-30',
#   'ya': False},
#  {'url': '/wiki/Red_Hot_Chili_Peppers',
#   'genre': ['Genre: /wiki/Rap_rock'],
#   'born': False,
#   'ya': ['1983', '–present']},
#  {'url': '/wiki/Color_Me_Badd',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': False,
#   'ya': ['1985', '–1998 ', ' 2010–present']},
#  {'url': '/wiki/Jon_Secada',
#   'genre': ['Genre: /wiki/Latin_pop'],
#   'born': '1961-10-04',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Shanice',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': '1973-05-14',
#   'ya': ['1984', 'present']},
#  {'url': '/wiki/Mr._Big_(band)',
#   'genre': ['Genre: /wiki/Glam_metal'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Right_Said_Fred',
#   'genre': ['Genre: /wiki/Dance-pop'],
#   'born': False,
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Michael_Jackson',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': '1958-08-29',
#   'ya': ['1964', '2009']},
#  {'url': '/wiki/Billy_Ray_Cyrus',
#   'genre': ['Genre: /wiki/Country_music'],
#   'born': '1961-08-25',
#   'ya': False},
#  {'url': '/wiki/Guns_N%27_Roses',
#   'genre': ['Genre: /wiki/Heavy_metal_music'],
#   'born': False,
#   'ya': ['1985', 'present']},
#  {'url': '/wiki/Tom_Cochrane',
#   'genre': ['Genre: /wiki/Country_music'],
#   'born': '1953-05-14',
#   'ya': ['1973', 'present']},
#  {'url': '/wiki/CeCe_Peniston',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': '1969-09-06',
#   'ya': False},
#  {'url': '/wiki/Madonna',
#   'genre': ['Genre: /wiki/Dance_music'],
#   'born': '1958-08-16',
#   'ya': False},
#  {'url': '/wiki/Patty_Smyth',
#   'genre': ['Genre: /wiki/New_wave_music'],
#   'born': '1957-06-26',
#   'ya': ['1981', 'present']},
#  {'url': '/wiki/Don_Henley',
#   'genre': ['Genre: /wiki/Folk_rock'],
#   'born': '1947-07-22',
#   'ya': ['1970', 'present']},
#  {'url': '/wiki/House_of_Pain',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1991', '1996, 2010', '2011, 2017']},
#  {'url': '/wiki/KWS_(band)',
#   'genre': ['Genre: /wiki/House_music'],
#   'born': False,
#   'ya': ['1991', '1994']},
#  {'url': '/wiki/Mint_Condition',
#   'genre': ['Genre: /wiki/Jazz'],
#   'born': False,
#   'ya': ['1984', 'present']},
#  {'url': '/wiki/The_Cover_Girls',
#   'genre': ['Genre: /wiki/Urban_contemporary'],
#   'born': False,
#   'ya': ['1986', '1996, 2001', 'present']},
#  {'url': '/wiki/Hi-Five',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': False,
#   'ya': ['1989–1994', '2012–present']},
#  {'url': '/wiki/N2Deep',
#   'genre': ['Genre: /wiki/Chicano_rap'],
#   'born': False,
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Kathy_Troccoli',
#   'genre': ['Genre: /wiki/Jazz'],
#   'born': '1958-06-24',
#   'ya': ['1982', '–present']},
#  {'url': '/wiki/Def_Leppard',
#   'genre': ['Genre: /wiki/Pop_rock'],
#   'born': False,
#   'ya': ['1977', 'present']},
#  {'url': '/wiki/Richard_Marx',
#   'genre': ['Genre: #cite_note-3'],
#   'born': '1963-09-16',
#   'ya': ['1980', 'present']},
#  {'url': '/wiki/FireHouse_(band)',
#   'genre': ['Genre: #cite_note-3'],
#   'born': False,
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Jade_(American_band)',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': False,
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Mary_J._Blige',
#   'genre': ['Genre: #cite_note-Bio-3'],
#   'born': '1971-01-11',
#   'ya': False},
#  {'url': '/wiki/The_KLF',
#   'genre': ['Genre: #cite_note-5'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Charles_%26_Eddie',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1990', '1995']},
#  {'url': '/wiki/Amy_Grant',
#   'genre': ['Genre: /wiki/Soft_rock'],
#   'born': '1960-11-25',
#   'ya': ['1976', 'present']},
#  {'url': '/wiki/Keith_Sweat',
#   'genre': ['Genre: /wiki/Urban_contemporary'],
#   'born': '1961-07-22',
#   'ya': ['1975', 'present']},
#  {'url': '/wiki/Das_EFX',
#   'genre': ['Genre: /wiki/Hardcore_hip_hop'],
#   'born': False,
#   'ya': ['1991–present']},
#  {'url': '/wiki/Bonnie_Raitt',
#   'genre': ['Genre: /wiki/Americana_(music)'],
#   'born': '1949-11-08',
#   'ya': ['1971', 'present']},
#  {'url': '/wiki/Michael_Bolton',
#   'genre': ['Genre: #cite_note-3'],
#   'born': '1953-02-26',
#   'ya': ['1975', 'present']},
#  {'url': '/wiki/Sir_Mix-a-Lot',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1963-08-12',
#   'ya': ['1979', 'present']},
#  {'url': '/wiki/Bryan_Adams',
#   'genre': ['Genre: /wiki/Soft_rock'],
#   'born': '1959-11-05',
#   'ya': ['1975', 'present']},
#  {'url': '/wiki/Toad_the_Wet_Sprocket',
#   'genre': ['Genre: /wiki/Alternative_rock'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Genesis_(band)',
#   'genre': ['Genre: #cite_note-5'],
#   'born': False,
#   'ya': ['Year Active: [6]', 'Year Active: [7]', 'Year Active: [8]']},
#  {'url': '/wiki/U2',
#   'genre': ['Genre: /wiki/Post-punk'],
#   'born': False,
#   'ya': ['1976', 'present']},
#  {'url': '/wiki/The_Heights_(American_TV_series)',
#   'genre': False,
#   'born': False,
#   'ya': False},
#  {'url': '/wiki/Karyn_White',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': '1965-10-14',
#   'ya': ['1985–2007', '2012–present']},
#  {'url': '/wiki/Peabo_Bryson',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1951-04-13',
#   'ya': ['1965', 'present']},
#  {'url': '/wiki/Marky_Mark_and_the_Funky_Bunch',
#   'genre': ['Genre: /wiki/Hip_house'],
#   'born': False,
#   'ya': ['1991', '1993']},
#  {'url': '/wiki/The_Cure',
#   'genre': ['Genre: /wiki/New_wave_music'],
#   'born': False,
#   'ya': ['1978', 'present']},
#  {'url': '/wiki/Ugly_Kid_Joe',
#   'genre': ['Genre: #cite_note-5'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Snap!',
#   'genre': ['Genre: /wiki/House_music'],
#   'born': False,
#   'ya': ['1989', '1996; 2000', 'present']},
#  {'url': '/wiki/Paula_Abdul',
#   'genre': ['Genre: /wiki/Dance_music'],
#   'born': '1962-06-19',
#   'ya': False},
#  {'url': '/wiki/Restless_Heart',
#   'genre': ['Genre: #cite_note-allmusic-1'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince',
#   'genre': ['Genre: /wiki/Golden_age_hip_hop'],
#   'born': False,
#   'ya': ['1986–1994', ' (Reunion; 2005, 2013, 2017, 2019)']},
#  {'url': '/wiki/Kenny_G',
#   'genre': ['Genre: /wiki/Easy_listening'],
#   'born': '1956-06-05',
#   'ya': []},
#  {'url': '/wiki/Boy_Krazy',
#   'genre': ['Genre: /wiki/Dance-pop'],
#   'born': False,
#   'ya': ['1991', '1993']},
#  {'url': '/wiki/Jeremy_Jordan_(singer,_born_1973)',
#   'genre': ['Genre: /wiki/Dance-pop'],
#   'born': '1973-09-19',
#   'ya': ['1992', '2010']},
#  {'url': '/wiki/Cypress_Hill',
#   'genre': ['Genre: /wiki/Rap_metal'],
#   'born': False,
#   'ya': ['1987–present']},
#  {'url': '/wiki/Snoop_Dogg',
#   'genre': ['Genre: /wiki/Reggae'],
#   'born': '1971-10-20',
#   'ya': False},
#  {'url': '/wiki/Positive_K',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1967-08-07',
#   'ya': ['1985', 'present']},
#  {'url': '/wiki/TLC_(group)',
#   'genre': ['Genre: #cite_note-2'],
#   'born': False,
#   'ya': ['1990–present']},
#  {'url': '/wiki/Aerosmith',
#   'genre': ['Genre: #cite_note-Aerosmith_glam3-3'],
#   'born': False,
#   'ya': ['1970–present']},
#  {'url': '/wiki/Portrait_(band)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1992', '1996; 2000', '2005; 2018', 'present']},
#  {'url': '/wiki/Bon_Jovi',
#   'genre': ['Genre: /wiki/Pop_rock'],
#   'born': False,
#   'ya': ['1983', 'present']},
#  {'url': '/wiki/Tupac_Shakur',
#   'genre': ['Genre: /wiki/West_Coast_hip_hop'],
#   'born': '1971-06-16',
#   'ya': False},
#  {'url': '/wiki/Xscape_(band)',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': False,
#   'ya': ['1992', '1998, 2001', '2006; 2017', 'present']},
#  {'url': '/wiki/Brian_McKnight',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1967-06-05',
#   'ya': False},
#  {'url': '/wiki/Dr._Dre',
#   'genre': ['Genre: /wiki/G-funk'],
#   'born': '1965-02-18',
#   'ya': False},
#  {'url': '/wiki/Zhan%C3%A9',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': False,
#   'ya': ['1993', '1999']},
#  {'url': '/wiki/Inner_Circle_(reggae_band)',
#   'genre': ['Genre: /wiki/Reggae_fusion'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Captain_Hollywood_Project',
#   'genre': ['Genre: /wiki/Eurodance'],
#   'born': False,
#   'ya': ['1992', '1996, 2008-present']},
#  {'url': '/wiki/Taylor_Dayne',
#   'genre': ['Genre: #cite_note-1'],
#   'born': '1962-03-07',
#   'ya': ['1985', 'present']},
#  {'url': '/wiki/Tony!_Toni!_Ton%C3%A9!',
#   'genre': ['Genre: #cite_note-2'],
#   'born': False,
#   'ya': ['1988–1997', '2003–present']},
#  {'url': '/wiki/Sting_(musician)',
#   'genre': ['Genre: #cite_note-Collins-3'],
#   'born': '1951-10-02',
#   'ya': False},
#  {'url': '/wiki/Gin_Blossoms',
#   'genre': ['Genre: /wiki/Jangle_pop'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Green_Jell%C3%BF',
#   'genre': ['Genre: /wiki/Alternative_metal'],
#   'born': False,
#   'ya': ['1981', '1995, 2008', 'present']},
#  {'url': '/wiki/Joey_Lawrence',
#   'genre': False,
#   'born': '1976-04-20',
#   'ya': False},
#  {'url': '/wiki/Ice_Cube',
#   'genre': ['Genre: /wiki/Political_hip_hop'],
#   'born': '1969-06-15',
#   'ya': False},
#  {'url': '/wiki/Tears_for_Fears',
#   'genre': ['Genre: #cite_note-7'],
#   'born': False,
#   'ya': ['1981', 'present']},
#  {'url': '/wiki/Go_West_(band)',
#   'genre': ['Genre: #cite_note-2'],
#   'born': False,
#   'ya': ['1982', 'present']},
#  {'url': '/wiki/Dino_(singer)',
#   'genre': ['Genre: /wiki/Freestyle_music'],
#   'born': '1963-07-20',
#   'ya': ['1988', '1993']},
#  {'url': '/wiki/Haddaway',
#   'genre': ['Genre: /wiki/Electronica'],
#   'born': '1965-01-09',
#   'ya': ['1987', 'present']},
#  {'url': '/wiki/Digable_Planets',
#   'genre': ['Genre: /wiki/Acid_jazz'],
#   'born': False,
#   'ya': ['1987', '1995, 2005', '2011, 2015', 'present']},
#  {'url': '/wiki/Rod_Stewart',
#   'genre': ['Genre: /wiki/Disco'],
#   'born': '1945-01-10',
#   'ya': ['1961', 'present']},
#  {'url': '/wiki/Prince_(musician)',
#   'genre': ['Genre: #cite_note-1'],
#   'born': '1958-06-07',
#   'ya': False},
#  {'url': '/wiki/4_Non_Blondes',
#   'genre': ['Genre: /wiki/Alternative_rock'],
#   'born': False,
#   'ya': ['1989', '1994 (one off reunion in 2014)']},
#  {'url': '/wiki/SWV',
#   'genre': ['Genre: /wiki/Urban_contemporary'],
#   'born': False,
#   'ya': ['1988–1998', '2005–present']},
#  {'url': '/wiki/Regina_Belle',
#   'genre': ['Genre: /wiki/Gospel_music'],
#   'born': '1963-07-17',
#   'ya': False},
#  {'url': '/wiki/Robin_S.',
#   'genre': ['Genre: /wiki/Jazz'],
#   'born': '1962-04-27',
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Duice',
#   'genre': ['Genre: /wiki/West_Coast_hip_hop'],
#   'born': False,
#   'ya': ['1992', '1995']},
#  {'url': '/wiki/H-Town_(band)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Snow_(musician)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1969-10-30',
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Wreckx-n-Effect',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': False,
#   'ya': ['1988', '1996; 2014-present']},
#  {'url': '/wiki/Shai_(band)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Silk_(group)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/UB40',
#   'genre': ['Genre: /wiki/Dub_music'],
#   'born': '1957-06-24',
#   'ya': ['1978', 'present']},
#  {'url': '/wiki/Tag_Team_(group)',
#   'genre': ['Genre: /wiki/Miami_bass'],
#   'born': False,
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Whitney_Houston',
#   'genre': ['Genre: /wiki/Dance_music'],
#   'born': '1963-08-09',
#   'ya': False},
#  {'url': '/wiki/Ace_of_Base',
#   'genre': ['Genre: #cite_note-Europop-5'],
#   'born': False,
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Soul_Asylum',
#   'genre': ['Genre: /wiki/Country_rock'],
#   'born': False,
#   'ya': ['1981', 'present']},
#  {'url': '/wiki/Expos%C3%A9_(group)',
#   'genre': ['Genre: /wiki/Pop-rock'],
#   'born': False,
#   'ya': ['1984–1996', '2003-present']},
#  {'url': '/wiki/Jade_(R%26B_group)',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': False,
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Billy_Joel',
#   'genre': ['Genre: #cite_note-concert_archives-2'],
#   'born': '1949-05-09',
#   'ya': ['1964', '–present']},
#  {'url': '/wiki/Paperboy_(rapper)',
#   'genre': False,
#   'born': False,
#   'ya': False},
#  {'url': '/wiki/Toni_Braxton',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': '1967-10-07',
#   'ya': False},
#  {'url': '/wiki/Naughty_by_Nature',
#   'genre': ['Genre: /wiki/East_Coast_hip_hop'],
#   'born': False,
#   'ya': ['1986–2002 ', ' 2006–present']},
#  {'url': '/wiki/95_South',
#   'genre': ['Genre: /wiki/Southern_hip_hop'],
#   'born': False,
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/Tina_Turner',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': '1939-11-26',
#   'ya': False},
#  {'url': '/wiki/Duran_Duran',
#   'genre': ['Genre: #cite_note-5'],
#   'born': False,
#   'ya': ['1978', 'present']},
#  {'url': '/wiki/Meat_Loaf',
#   'genre': ['Genre: /wiki/Wagnerian_rock'],
#   'born': '1947-09-27',
#   'ya': ['1968', 'present']},
#  {'url': '/wiki/Spin_Doctors',
#   'genre': ['Genre: #cite_note-1'],
#   'born': False,
#   'ya': ['1988', '1999, 2001', 'present']},
#  {'url': '/wiki/The_Proclaimers',
#   'genre': ['Genre: /wiki/Roots_rock'],
#   'born': '1962-03-05',
#   'ya': ['1983', 'present']},
#  {'url': '/wiki/Onyx_(hip_hop_group)',
#   'genre': ['Genre: #cite_note-allmusic-1'],
#   'born': False,
#   'ya': ['1988', '–present']},
#  {'url': '/wiki/Culture_Beat',
#   'genre': ['Genre: #cite_note-2'],
#   'born': False,
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Babyface_(musician)',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': '1959-04-10',
#   'ya': False},
#  {'url': '/wiki/Aaliyah',
#   'genre': ['Genre: /wiki/Neo_soul'],
#   'born': '1979-01-16',
#   'ya': False},
#  {'url': '/wiki/Gabrielle_(singer)',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1969-07-19',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Erasure',
#   'genre': ['Genre: /wiki/Dance_music'],
#   'born': False,
#   'ya': ['1985', 'present']},
#  {'url': '/wiki/Jimmy_Cliff',
#   'genre': ['Genre: /wiki/Reggae'],
#   'born': '1948-04-01',
#   'ya': ['1962', 'present']},
#  {'url': '/wiki/69_Boyz',
#   'genre': ['Genre: /wiki/Southern_hip_hop'],
#   'born': False,
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Warren_G',
#   'genre': ['Genre: /wiki/G-funk'],
#   'born': '1970-11-10',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Real_McCoy_(band)',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': False,
#   'ya': ['1987', '1997, 1999-2001, 2006-2009, 2016', 'present']},
#  {'url': '/wiki/Aaron_Hall_(musician)',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': '1964-08-10',
#   'ya': ['1988', 'present']},
#  {'url': '/wiki/Domino_(rapper)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Bruce_Springsteen',
#   'genre': ['Genre: /wiki/Americana_(music)'],
#   'born': '1949-09-23',
#   'ya': ['1964', 'present']},
#  {'url': '/wiki/R._Kelly',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1967-01-08',
#   'ya': False},
#  {'url': '/wiki/Tom_Petty_and_the_Heartbreakers',
#   'genre': ['Genre: /wiki/Southern_rock'],
#   'born': False,
#   'ya': ['1976', '2017']},
#  {'url': '/wiki/IMx',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1990', '2002, 2009', 'present']},
#  {'url': '/wiki/Joshua_Kadison',
#   'genre': ['Genre: /wiki/Adult_contemporary'],
#   'born': '1963-02-08',
#   'ya': ['1992', '2012; (2012-present, on/off appearance)']},
#  {'url': '/wiki/Brandy_Norwood',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1979-02-11',
#   'ya': False},
#  {'url': '/wiki/George_Clinton_(funk_musician)',
#   'genre': ['Genre: #cite_note-3'],
#   'born': '1941-07-22',
#   'ya': ['1955–present']},
#  {'url': '/wiki/General_Public',
#   'genre': ['Genre: /wiki/New_wave_music'],
#   'born': False,
#   'ya': ['1983', '1987, 1994', '1995']},
#  {'url': '/wiki/Ahmad_(rapper)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1975-10-12',
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/Melissa_Etheridge',
#   'genre': ['Genre: /wiki/Country_rock'],
#   'born': '1961-05-29',
#   'ya': False},
#  {'url': '/wiki/Tim_McGraw',
#   'genre': ['Genre: /wiki/Country_music'],
#   'born': '1967-05-01',
#   'ya': False},
#  {'url': '/wiki/The_Four_Seasons_(band)',
#   'genre': ['Genre: /wiki/Disco'],
#   'born': False,
#   'ya': ['1960', '1977, 1979', 'present']},
#  {'url': '/wiki/Heavy_D',
#   'genre': ['Genre: /wiki/Reggae_fusion'],
#   'born': '1967-05-24',
#   'ya': ['1986', '2011']},
#  {'url': '/wiki/Phil_Collins',
#   'genre': ['Genre: #cite_note-7'],
#   'born': '1951-01-30',
#   'ya': False},
#  {'url': '/wiki/Ini_Kamoze',
#   'genre': ['Genre: /wiki/Reggae_fusion'],
#   'born': '1957-10-09',
#   'ya': ['1981', 'present']},
#  {'url': '/wiki/Seal_(musician)',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1963-02-19',
#   'ya': ['1987', 'present']},
#  {'url': '/wiki/Queen_Latifah',
#   'genre': ['Genre: /wiki/Dance_music'],
#   'born': '1970-03-18',
#   'ya': False},
#  {'url': '/wiki/Craig_Mack',
#   'genre': ['Genre: /wiki/East_Coast_hip_hop'],
#   'born': '1970-05-10',
#   'ya': False},
#  {'url': '/wiki/Eternal_(band)',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Beck',
#   'genre': ['Genre: /wiki/Lo-fi_music'],
#   'born': '1970-07-08',
#   'ya': False},
#  {'url': '/wiki/Big_Mountain_(band)',
#   'genre': ['Genre: /wiki/Reggae'],
#   'born': False,
#   'ya': ['1988', 'present']},
#  {'url': '/wiki/Coolio',
#   'genre': ['Genre: /wiki/West_Coast_hip_hop'],
#   'born': '1963-08-01',
#   'ya': ['1987–present']},
#  {'url': '/wiki/Meshell_Ndegeocello',
#   'genre': ['Genre: #cite_note-1'],
#   'born': '1968-08-29',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/John_Mellencamp',
#   'genre': ['Genre: /wiki/Country_rock'],
#   'born': '1951-10-07',
#   'ya': ['1976', 'present']},
#  {'url': '/wiki/Salt-n-Pepa',
#   'genre': ['Genre: /wiki/Dance-pop'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Lisa_Loeb',
#   'genre': ['Genre: /wiki/Children%27s_music'],
#   'born': '1968-03-11',
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/C%C3%A9line_Dion',
#   'genre': ['Genre: /wiki/Soft_rock'],
#   'born': '1968-03-30',
#   'ya': False},
#  {'url': '/wiki/All-4-One',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': False,
#   'ya': ['1993', '–present']},
#  {'url': '/wiki/Nate_Dogg',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': '1969-08-19',
#   'ya': ['1990', '2008']},
#  {'url': '/wiki/The_Cranberries',
#   'genre': ['Genre: /wiki/Post-punk'],
#   'born': False,
#   'ya': ['Year Active: [1]']},
#  {'url': '/wiki/Crystal_Waters',
#   'genre': ['Genre: /wiki/Electronic_music'],
#   'born': '1961-11-19',
#   'ya': False},
#  {'url': '/wiki/Changing_Faces_(group)',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': False,
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/10,000_Maniacs',
#   'genre': ['Genre: /wiki/College_rock'],
#   'born': False,
#   'ya': ['1981', 'present']},
#  {'url': '/wiki/DRS_(group)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1990s']},
#  {'url': '/wiki/Da_Brat',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1974-04-14',
#   'ya': False},
#  {'url': '/wiki/Us3',
#   'genre': False,
#   'born': False,
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Crash_Test_Dummies',
#   'genre': ['Genre: /wiki/Folk_rock'],
#   'born': False,
#   'ya': ['1988', 'present']},
#  {'url': '/wiki/Enigma_(German_band)',
#   'genre': ['Genre: /wiki/Experimental_music'],
#   'born': False,
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Sheryl_Crow',
#   'genre': ['Genre: /wiki/Americana_(music)'],
#   'born': '1962-02-11',
#   'ya': ['1986', 'present']},
#  {'url': '/wiki/Collective_Soul',
#   'genre': ['Genre: #cite_note-AM-1'],
#   'born': False,
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/20_Fingers',
#   'genre': ['Genre: /wiki/Eurodance'],
#   'born': False,
#   'ya': ['1994–1995 (as artist)', '1996–present (as producers)']},
#  {'url': '/wiki/Gillette_(singer)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1974-09-16',
#   'ya': ['1994', '2004']},
#  {'url': '/wiki/Jade_(American_group)',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': False,
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/The_Notorious_B.I.G.',
#   'genre': ['Genre: /wiki/East_Coast_hip_hop'],
#   'born': '1972-05-21',
#   'ya': False},
#  {'url': '/wiki/Junior_M.A.F.I.A.',
#   'genre': ['Genre: /wiki/Hardcore_hip_hop'],
#   'born': False,
#   'ya': ['1994–1997,', '2004–2007,', '2019']},
#  {'url': '/wiki/702_(band)',
#   'genre': ['Genre: #cite_note-1'],
#   'born': False,
#   'ya': ['1993', '2006, 2017-present']},
#  {'url': '/wiki/Skee-Lo',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1975-03-27',
#   'ya': ['1994–present']},
#  {'url': '/wiki/Total_(band)',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': False,
#   'ya': ['1994', '2001, 2014', 'present']},
#  {'url': '/wiki/Groove_Theory',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': False,
#   'ya': ['1993', '2001, 2010', 'present']},
#  {'url': '/wiki/Take_That',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Tom_Petty',
#   'genre': ['Genre: /wiki/Southern_rock'],
#   'born': '1950-10-20',
#   'ya': False},
#  {'url': '/wiki/Natalie_Merchant',
#   'genre': ['Genre: /wiki/Folk_rock'],
#   'born': '1963-10-26',
#   'ya': ['1981', 'present']},
#  {'url': '/wiki/Brandy_(entertainer)',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1979-02-11',
#   'ya': False},
#  {'url': '/wiki/Subway_(group)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1992', '1998']},
#  {'url': '/wiki/Wanya_Morris',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': '1973-07-29',
#   'ya': ['1988–present']},
#  {'url': '/wiki/Shaggy_(musician)',
#   'genre': ['Genre: /wiki/Dancehall'],
#   'born': '1968-10-22',
#   'ya': False},
#  {'url': '/wiki/Faith_Evans',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1973-06-10',
#   'ya': False},
#  {'url': '/wiki/Van_Halen',
#   'genre': ['Genre: /wiki/Glam_metal'],
#   'born': False,
#   'ya': ['1974–2020']},
#  {'url': '/wiki/N_II_U', 'genre': False, 'born': False, 'ya': False},
#  {'url': '/wiki/The_Pretenders',
#   'genre': ['Genre: #cite_note-1'],
#   'born': False,
#   'ya': ['1978', 'present']},
#  {'url': '/wiki/Rednex',
#   'genre': ['Genre: /wiki/Folktronica'],
#   'born': False,
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Stevie_B',
#   'genre': ['Genre: /wiki/Electronic_music'],
#   'born': '1958-04-19',
#   'ya': ['1987', 'present']},
#  {'url': '/wiki/FireHouse',
#   'genre': ['Genre: #cite_note-3'],
#   'born': False,
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Bone_Thugs-n-Harmony',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1991–present']},
#  {'url': '/wiki/After_7',
#   'genre': ['Genre: #cite_note-2'],
#   'born': False,
#   'ya': ['1987', '1997; 2006', 'present']},
#  {'url': '/wiki/Gloria_Estefan',
#   'genre': ['Genre: /wiki/Dance-pop'],
#   'born': '1957-09-01',
#   'ya': ['1975', 'present']},
#  {'url': '/wiki/D%27Angelo',
#   'genre': ['Genre: #cite_note-2'],
#   'born': '1974-02-11',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Better_Than_Ezra',
#   'genre': ['Genre: #cite_note-allmusic-bio-1'],
#   'born': False,
#   'ya': ['1988', 'present']},
#  {'url': '/wiki/AZ_(rapper)',
#   'genre': ['Genre: /wiki/Gangsta_rap'],
#   'born': '1972-03-09',
#   'ya': ['1992 - present']},
#  {'url': '/wiki/Raphael_Saadiq',
#   'genre': ['Genre: #cite_note-3'],
#   'born': '1966-05-14',
#   'ya': ['1983', 'present']},
#  {'url': '/wiki/Annie_Lennox',
#   'genre': ['Genre: /wiki/Jazz'],
#   'born': '1954-12-25',
#   'ya': ['1976', 'present']},
#  {'url': '/wiki/Corona_(group)',
#   'genre': ['Genre: /wiki/Eurodance'],
#   'born': False,
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/Soul_for_Real',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': False,
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Hootie_%26_the_Blowfish',
#   'genre': ['Genre: /wiki/Country_music'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Des%27ree',
#   'genre': ['Genre: /wiki/Adult_contemporary'],
#   'born': '1968-11-30',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Nicki_French',
#   'genre': ['Genre: /wiki/Eurodance'],
#   'born': '1964-09-26',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Adina_Howard',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1973-11-14',
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Dionne_Farris',
#   'genre': ['Genre: /wiki/Jazz'],
#   'born': '1969-12-04',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Montell_Jordan',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1968-12-03',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Monica_(singer)',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': '1980-10-24',
#   'ya': False},
#  {'url': '/wiki/L.V._(singer)',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1957-11-21',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Del_Amitri',
#   'genre': ['Genre: /wiki/Alternative_rock'],
#   'born': False,
#   'ya': ['1980', '2002, 2013', 'present']},
#  {'url': '/wiki/Blessid_Union_of_Souls',
#   'genre': ['Genre: #cite_note-1'],
#   'born': False,
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Blues_Traveler',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': False,
#   'ya': ['1987', 'present']},
#  {'url': '/wiki/Jamie_Walters',
#   'genre': ['Genre: '],
#   'born': '1969-06-13',
#   'ya': ['1992', '2003, 2019']},
#  {'url': '/wiki/4_P.M._(group)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1991', '2008']},
#  {'url': '/wiki/Diana_King',
#   'genre': ['Genre: /wiki/Dancehall'],
#   'born': '1970-11-08',
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/Method_Man',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1971-03-02',
#   'ya': ['1988', 'present']},
#  {'url': '/wiki/Blackstreet',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1993–2003;', ' 2014–present']},
#  {'url': '/wiki/Jon_B.',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1974-11-11',
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Martin_Page',
#   'genre': ['Genre: /wiki/Adult_contemporary_music'],
#   'born': '1959-09-23',
#   'ya': ['1981', 'present']},
#  {'url': '/wiki/Brownstone_(group)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1994', '1998; 2014-2015, 2019-present']},
#  {'url': '/wiki/MoKenStef',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1994–2000', '2014–present']},
#  {'url': '/wiki/Luniz',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1994 ', ' present']},
#  {'url': '/wiki/Deborah_Cox',
#   'genre': ['Genre: /wiki/Jazz'],
#   'born': '1974-07-13',
#   'ya': ['1987', 'present']},
#  {'url': '/wiki/Amber_(performer)',
#   'genre': ['Genre: /wiki/Pop_rock'],
#   'born': '1969-09-17',
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/New_Edition',
#   'genre': ['Genre: #cite_note-3'],
#   'born': False,
#   'ya': ['1978–1990,', ' 1996–97, 2002–present']},
#  {'url': '/wiki/Total_(group)',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': False,
#   'ya': ['1994', '2001, 2014', 'present']},
#  {'url': '/wiki/Ghost_Town_DJ%27s',
#   'genre': ['Genre: /wiki/Miami_bass'],
#   'born': False,
#   'ya': ['1995', '1997']},
#  {'url': '/wiki/Planet_Soul',
#   'genre': ['Genre: /wiki/Techno'],
#   'born': False,
#   'ya': False},
#  {'url': '/wiki/No_Doubt',
#   'genre': ['Genre: /wiki/Synth-pop'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/MC_Lyte',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1970-10-11',
#   'ya': ['1987', 'present']},
#  {'url': '/wiki/Athena_Cage',
#   'genre': ['Genre: '],
#   'born': '1969-03-06',
#   'ya': ['Present']},
#  {'url': '/wiki/Ginuwine',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1970-10-15',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/BoDeans',
#   'genre': ['Genre: /wiki/Alternative_rock'],
#   'born': False,
#   'ya': ['1983', 'present']},
#  {'url': '/wiki/Larry_Mullen,_Jr.',
#   'genre': ['Genre: /wiki/Alternative_rock'],
#   'born': '1961-10-31',
#   'ya': ['1976', 'present']},
#  {'url': '/wiki/Maxi_Priest',
#   'genre': ['Genre: /wiki/Lovers_rock'],
#   'born': '1961-06-10',
#   'ya': ['1984', 'present']},
#  {'url': '/wiki/Twista',
#   'genre': ['Genre: /wiki/Chopper_(rap)'],
#   'born': '1973-11-27',
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Adam_Clayton',
#   'genre': ['Genre: /wiki/Post-punk'],
#   'born': '1960-03-13',
#   'ya': ['1976', 'present']},
#  {'url': '/wiki/2Pac',
#   'genre': ['Genre: /wiki/West_Coast_hip_hop'],
#   'born': '1971-06-16',
#   'ya': False},
#  {'url': '/wiki/K-Ci_and_JoJo',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': False,
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/Alanis_Morissette',
#   'genre': ['Genre: /wiki/Dance-pop'],
#   'born': '1974-06-01',
#   'ya': ['1986', 'present']},
#  {'url': '/wiki/Los_del_R%C3%ADo',
#   'genre': ['Genre: /wiki/Sevillanas'],
#   'born': False,
#   'ya': ['1962', 'present']},
#  {'url': '/wiki/Pearl_Jam',
#   'genre': ['Genre: /wiki/Hard_rock'],
#   'born': False,
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Crucial_Conflict',
#   'genre': False,
#   'born': False,
#   'ya': ['1991', '1999, 2007', 'present']},
#  {'url': '/wiki/Metallica',
#   'genre': ['Genre: /wiki/Speed_metal'],
#   'born': False,
#   'ya': ['1981', 'present']},
#  {'url': '/wiki/Do_or_Die_(group)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Robert_Miles',
#   'genre': ['Genre: /wiki/Experimental_music'],
#   'born': '1969-11-03',
#   'ya': ['1984', '2017']},
#  {'url': '/wiki/Foxy_Brown_(rapper)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1978-09-06',
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Joan_Osborne',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1962-07-08',
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Dishwalla',
#   'genre': ['Genre: /wiki/Post-grunge'],
#   'born': False,
#   'ya': ['1993', '2005, 2008', 'present']},
#  {'url': '/wiki/No_Mercy_(pop_band)',
#   'genre': ['Genre: /wiki/Dance-pop'],
#   'born': False,
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Tony_Rich',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1971-11-19',
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/Tracy_Chapman',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1964-03-30',
#   'ya': ['1986', 'present']},
#  {'url': '/wiki/Quad_City_DJ%27s',
#   'genre': ['Genre: /wiki/Miami_bass'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Everything_but_the_Girl',
#   'genre': ['Genre: #cite_note-4'],
#   'born': False,
#   'ya': ['1982', '2000']},
#  {'url': '/wiki/LL_Cool_J',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1968-01-14',
#   'ya': ['1984', 'present']},
#  {'url': '/wiki/Jann_Arden',
#   'genre': ['Genre: '],
#   'born': '1962-03-27',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/La_Bouche',
#   'genre': ['Genre: /wiki/House_music'],
#   'born': False,
#   'ya': ['1994', '2002, 2007', 'present']},
#  {'url': '/wiki/Goo_Goo_Dolls',
#   'genre': ['Genre: #cite_note-allmusic-bio-1'],
#   'born': False,
#   'ya': ['1986', 'present']},
#  {'url': '/wiki/Jewel_(singer)',
#   'genre': ['Genre: /wiki/Country_music'],
#   'born': '1974-05-23',
#   'ya': False},
#  {'url': '/wiki/Donna_Lewis',
#   'genre': ['Genre: /wiki/Folk_music'],
#   'born': False,
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/112_(band)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1993–present']},
#  {'url': '/wiki/Mase',
#   'genre': ['Genre: #cite_note-allmusic-2'],
#   'born': '1975-08-27',
#   'ya': ['1993', '1999, 2004', '2006, 2009', 'present']},
#  {'url': '/wiki/Case_(singer)',
#   'genre': ['Genre: /wiki/Urban_contemporary'],
#   'born': '1975-10-04',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Busta_Rhymes',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1972-05-20',
#   'ya': ['1994', '2014']},
#  {'url': '/wiki/Oasis_(band)',
#   'genre': ['Genre: /wiki/Britpop'],
#   'born': False,
#   'ya': ['1991', '2009']},
#  {'url': '/wiki/Joe_(singer)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1973-07-05',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Merril_Bainbridge',
#   'genre': False,
#   'born': '1968-06-02',
#   'ya': ['1977', '2003, 2015', 'present']},
#  {'url': '/wiki/Az_Yet',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Outkast',
#   'genre': ['Genre: /wiki/Southern_hip_hop'],
#   'born': False,
#   'ya': ['1992', '2006']},
#  {'url': '/wiki/CeCe_Winans',
#   'genre': ['Genre: /wiki/Urban_contemporary_gospel'],
#   'born': '1964-10-08',
#   'ya': ['1984', 'present']},
#  {'url': '/wiki/The_Isley_Brothers',
#   'genre': ['Genre: /wiki/Progressive_soul'],
#   'born': False,
#   'ya': ['1954', 'present']},
#  {'url': '/wiki/Deep_Blue_Something',
#   'genre': ['Genre: #cite_note-1'],
#   'born': False,
#   'ya': ['1991', '2001, 2014', 'present']},
#  {'url': '/wiki/3T',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': False,
#   'ya': ['1994–2012,', ' 2013–present']},
#  {'url': '/wiki/The_Smashing_Pumpkins',
#   'genre': ['Genre: /wiki/Alternative_rock'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Lil%27_Kim',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': False},
#  {'url': '/wiki/Erykah_Badu',
#   'genre': ['Genre: #cite_note-2'],
#   'born': '1971-02-26',
#   'ya': False},
#  {'url': '/wiki/Sean_Combs',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1969-11-04',
#   'ya': False},
#  {'url': '/wiki/Luscious_Jackson',
#   'genre': ['Genre: /wiki/Trip_hop'],
#   'born': False,
#   'ya': ['1991', '2000, 2011', 'present']},
#  {'url': '/wiki/Scarface_(rapper)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1970-11-09',
#   'ya': ['1988', 'present']},
#  {'url': '/wiki/Chumbawamba',
#   'genre': ['Genre: #cite_note-5'],
#   'born': False,
#   'ya': ['1982', '2012']},
#  {'url': 'nan', 'genre': False, 'born': False, 'ya': False},
#  {'url': '/wiki/B-Rock_and_the_Bizz',
#   'genre': False,
#   'born': False,
#   'ya': False},
#  {'url': '/wiki/White_Town',
#   'genre': ['Genre: /wiki/Trip_hop'],
#   'born': False,
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Sarah_McLachlan',
#   'genre': ['Genre: /wiki/Adult_contemporary'],
#   'born': '1968-01-28',
#   'ya': ['1987', 'present']},
#  {'url': '/wiki/Ray_J',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': '1981-01-17',
#   'ya': False},
#  {'url': '/wiki/The_Blackout_All-Stars',
#   'genre': False,
#   'born': False,
#   'ya': ['1994']},
#  {'url': '/wiki/DJ_Kool',
#   'genre': ['Genre: /wiki/Go-go'],
#   'born': '1958-03-20',
#   'ya': ['1979', 'present']},
#  {'url': '/wiki/Aqua_(band)',
#   'genre': ['Genre: #cite_note-5'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Mr._President_(band)',
#   'genre': ['Genre: /wiki/Reggae_fusion'],
#   'born': False,
#   'ya': ['1991', '2008']},
#  {'url': '/wiki/Next_(group)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Peter_Cetera',
#   'genre': ['Genre: /wiki/Jazz_fusion'],
#   'born': '1944-09-13',
#   'ya': ['1962', '2018']},
#  {'url': '/wiki/The_Verve_Pipe',
#   'genre': ['Genre: #cite_note-Villains_AMG-1'],
#   'born': False,
#   'ya': ['1992', '–present']},
#  {'url': '/wiki/Savage_Garden',
#   'genre': ['Genre: #cite_note-2'],
#   'born': False,
#   'ya': ['1994', '2001']},
#  {'url': '/wiki/Rome_(musician)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1968-03-05',
#   'ya': ['1996', '2003, 2009', 'present']},
#  {'url': '/wiki/Dru_Hill',
#   'genre': ['Genre: /wiki/Gospel_music'],
#   'born': False,
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Spice_Girls',
#   'genre': ['Genre: /wiki/Dance-pop'],
#   'born': False,
#   'ya': ['1994',
#    '–2001, 2007',
#    '–2008, 2012',
#    ', 2016',
#    ', 2018',
#    '–present']},
#  {'url': '/wiki/Robyn',
#   'genre': ['Genre: #cite_note-6'],
#   'born': '1979-06-12',
#   'ya': False},
#  {'url': '/wiki/Duncan_Sheik',
#   'genre': ['Genre: /wiki/Pop_rock'],
#   'born': '1969-11-18',
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/Third_Eye_Blind',
#   'genre': ['Genre: #cite_note-4'],
#   'born': False,
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/LeAnn_Rimes',
#   'genre': ['Genre: /wiki/Dance-pop'],
#   'born': '1982-08-28',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Backstreet_Boys',
#   'genre': ['Genre: /wiki/Adult_contemporary_music'],
#   'born': False,
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/Usher_(entertainer)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1978-10-14',
#   'ya': False},
#  {'url': '/wiki/Meredith_Brooks',
#   'genre': False,
#   'born': '1958-06-12',
#   'ya': ['1976', '2007 (as artist)']},
#  {'url': '/wiki/Mark_Morrison',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1972-05-03',
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/Hanson_(band)',
#   'genre': ['Genre: #cite_note-2'],
#   'born': False,
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Somethin%27_for_the_People',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1990', '2000']},
#  {'url': '/wiki/Trina_%26_Tamara',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1990s']},
#  {'url': '/wiki/Barbra_Streisand',
#   'genre': ['Genre: /wiki/Disco'],
#   'born': '1942-04-24',
#   'ya': ['1960', 'present']},
#  {'url': '/wiki/Jay-Z',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1969-12-04',
#   'ya': False},
#  {'url': '/wiki/Journey_(band)',
#   'genre': ['Genre: #cite_note-6'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Timbaland_%26_Magoo',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1989', '2004']},
#  {'url': '/wiki/Missy_Elliott',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1971-07-01',
#   'ya': False},
#  {'url': '/wiki/Angie_Martinez',
#   'genre': ['Genre: /wiki/Latino_rap'],
#   'born': '1971-01-09',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Lisa_Lopes',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1971-05-27',
#   'ya': ['1991–2002']},
#  {'url': '/wiki/Freak_Nasty',
#   'genre': ['Genre: #cite_note-All_Music_Bio-2'],
#   'born': False,
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Sister_Hazel',
#   'genre': ['Genre: #cite_note-4'],
#   'born': False,
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/Shawn_Colvin',
#   'genre': ['Genre: /wiki/Country_Folk'],
#   'born': '1956-01-10',
#   'ya': ['1973', 'present']},
#  {'url': '/wiki/Faith_Hill',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': '1967-09-21',
#   'ya': False},
#  {'url': '/wiki/Paula_Cole',
#   'genre': ['Genre: #cite_note-1'],
#   'born': '1968-04-05',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Allure_(group)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/98_Degrees',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': False,
#   'ya': ['1996', '2002, 2012', 'present']},
#  {'url': '/wiki/Gina_G',
#   'genre': ['Genre: /wiki/Eurodance'],
#   'born': '1970-08-03',
#   'ya': ['1990', '1998, 2004', 'present']},
#  {'url': '/wiki/Monifah',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1972-01-28',
#   'ya': False},
#  {'url': '/wiki/DMX_(rapper)',
#   'genre': ['Genre: #cite_note-allmusic-2'],
#   'born': '1970-12-18',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/The_Verve',
#   'genre': ['Genre: #cite_note-allmusic-2'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Edwin_McCain',
#   'genre': ['Genre: /wiki/Indie_rock'],
#   'born': '1970-01-20',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/The_LOX',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Pras',
#   'genre': ['Genre: /wiki/Reggae'],
#   'born': '1972-10-19',
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Kelly_Price',
#   'genre': ['Genre: /wiki/Gospel_music'],
#   'born': '1973-04-04',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Redman_(rapper)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1970-04-17',
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/M%C3%BDa',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1979-10-10',
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/Ol%27_Dirty_Bastard',
#   'genre': ['Genre: /wiki/Hardcore_hip_hop'],
#   'born': '1968-11-15',
#   'ya': False},
#  {'url': '/wiki/Ronald_Isley',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1941-05-21',
#   'ya': ['1954', 'present']},
#  {'url': '/wiki/TQ_(singer)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1976-05-24',
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Gerald_Levert',
#   'genre': ['Genre: /wiki/New_jack_swing'],
#   'born': '1966-07-13',
#   'ya': ['1983', '2006']},
#  {'url': '/wiki/Aretha_Franklin',
#   'genre': ['Genre: /wiki/Rock_music'],
#   'born': '1942-03-25',
#   'ya': False},
#  {'url': '/wiki/Loreena_McKennitt',
#   'genre': ['Genre: /wiki/New-age_music'],
#   'born': '1957-02-17',
#   'ya': ['1985', '1998, 2006', '2019']},
#  {'url': '/wiki/Jermaine_Dupri',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1972-09-23',
#   'ya': False},
#  {'url': '/wiki/Nu_Flavor',
#   'genre': False,
#   'born': False,
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/No_Good_But_So_Good',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1992', '2005']},
#  {'url': '/wiki/Luther_Campbell',
#   'genre': ['Genre: /wiki/Miami_bass'],
#   'born': '1960-12-22',
#   'ya': False},
#  {'url': '/wiki/INOJ',
#   'genre': ['Genre: /wiki/Miami_bass'],
#   'born': '1976-11-27',
#   'ya': ['1997', 'present']},
#  {'url': '/wiki/Big_Pun',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1971-11-10',
#   'ya': ['1995–2000']},
#  {'url': '/wiki/Sons_of_Funk',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': False,
#   'ya': ['1997—1999, 2014-present']},
#  {'url': '/wiki/Jennifer_Paige',
#   'genre': ['Genre: /wiki/Pop_rock'],
#   'born': '1973-09-03',
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Public_Announcement',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Uncle_Sam_(singer)',
#   'genre': False,
#   'born': False,
#   'ya': False},
#  {'url': '/wiki/Master_P',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1970-04-29',
#   'ya': False},
#  {'url': '/wiki/Silkk_the_Shocker',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1975-06-18',
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/Marcy_Playground',
#   'genre': ['Genre: /wiki/Post-grunge'],
#   'born': False,
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Wyclef_Jean',
#   'genre': ['Genre: /wiki/Neo_soul'],
#   'born': '1969-10-17',
#   'ya': False},
#  {'url': '/wiki/Monica_(entertainer)',
#   'genre': ['Genre: /wiki/Hip_hop_soul'],
#   'born': '1980-10-24',
#   'ya': False},
#  {'url': '/wiki/Shania_Twain',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': '1965-08-28',
#   'ya': False},
#  {'url': '/wiki/K-Ci_%26_JoJo',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': False,
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/LSG_(band)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1996', '2003; 2013', 'present (reunion)']},
#  {'url': '/wiki/Destiny%27s_Child',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': ['1990', '–2006']},
#  {'url': '/wiki/Will_Smith',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1968-09-25',
#   'ya': False},
#  {'url': '/wiki/Usher_(singer)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1978-10-14',
#   'ya': False},
#  {'url': '/wiki/%27N_Sync',
#   'genre': ['Genre: /wiki/Teen_pop'],
#   'born': False,
#   'ya': ['1995–2002']},
#  {'url': '/wiki/Barenaked_Ladies',
#   'genre': ['Genre: #cite_note-Cantrell-2'],
#   'born': False,
#   'ya': ['1988', 'present']},
#  {'url': '/wiki/K._P._%26_Envyi', 'genre': False, 'born': False, 'ya': False},
#  {'url': '/wiki/Tatyana_Ali',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1979-01-24',
#   'ya': False},
#  {'url': '/wiki/Divine_(band)', 'genre': False, 'born': False, 'ya': False},
#  {'url': '/wiki/Jimmy_Ray',
#   'genre': ['Genre: /wiki/Pop_rock'],
#   'born': '1970-10-03',
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Lord_Tariq_and_Peter_Gunz',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1996', '1999']},
#  {'url': '/wiki/Sisqo',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': '1978-11-09',
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Mystikal',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1970-09-22',
#   'ya': []},
#  {'url': '/wiki/Five_(band)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Fiend_(rapper)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1976-05-13',
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Mia_X',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1970-01-09',
#   'ya': ['1984', '1999, 2008', 'present']},
#  {'url': '/wiki/Nicole_Wray',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1979-05-02',
#   'ya': ['1997', 'present']},
#  {'url': '/wiki/All_Saints_(group)',
#   'genre': ['Genre: /wiki/Electronica'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Voices_of_Theory',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': False,
#   'ya': False},
#  {'url': '/wiki/Billie_Myers',
#   'genre': ['Genre: /wiki/Pop_rock'],
#   'born': '1971-06-14',
#   'ya': ['1997', 'present']},
#  {'url': '/wiki/Jimmy_Page',
#   'genre': ['Genre: /wiki/Heavy_metal_music'],
#   'born': '1944-01-09',
#   'ya': False},
#  {'url': '/wiki/Sylk-E._Fyne',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1978-07-12',
#   'ya': ['1994 ', ' Present']},
#  {'url': '/wiki/Marc_Anthony',
#   'genre': ['Genre: /wiki/Soft_rock'],
#   'born': '1968-09-16',
#   'ya': False},
# ...
#  {'url': '/wiki/Yanou',
#   'genre': ['Genre: /wiki/Eurodance'],
#   'born': '1974-03-06',
#   'ya': ['1997', 'present']},
#  {'url': '/wiki/Five_for_Fighting',
#   'genre': ['Genre: #cite_note-8'],
#   'born': '1965-01-07',
#   'ya': ['1988–present']},
#  {'url': '/wiki/Kylie_Minogue',
#   'genre': ['Genre: /wiki/Disco'],
#   'born': '1968-05-28',
#   'ya': False},
#  {'url': '/wiki/Charli_Baltimore',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1974-08-16',
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/John_Mayer',
#   'genre': ['Genre: /wiki/Blues_rock'],
#   'born': '1977-10-16',
#   'ya': False},
#  {'url': '/wiki/Rakim',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1968-01-28',
#   'ya': ['1985', 'present']},
#  {'url': '/wiki/Kelly_Clarkson',
#   'genre': ['Genre: #cite_note-3'],
#   'born': '1982-04-24',
#   'ya': False},
#  {'url': '/wiki/Tweet_(singer)',
#   'genre': ['Genre: /wiki/Neo_soul'],
#   'born': '1971-01-21',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/N.O.R.E.',
#   'genre': ['Genre: /wiki/Reggaeton'],
#   'born': '1977-09-06',
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Mario_(entertainer)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1986-08-27',
#   'ya': ['2005—2010']},
#  {'url': '/wiki/DJ_Sammy',
#   'genre': False,
#   'born': '1969-10-19',
#   'ya': ['1984', 'present']},
#  {'url': '/wiki/Nickelback',
#   'genre': ['Genre: /wiki/Alternative_rock'],
#   'born': False,
#   'ya': ['1995', '–present']},
#  {'url': '/wiki/Truth_Hurts_(singer)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1971-10-10',
#   'ya': ['1997', 'present']},
#  {'url': '/wiki/Big_Tymers',
#   'genre': ['Genre: /wiki/Southern_hip_hop'],
#   'born': False,
#   'ya': ['1997–2005;', ' 2018']},
#  {'url': '/wiki/Do_(singer)',
#   'genre': ['Genre: /wiki/Nederpop'],
#   'born': '1981-09-07',
#   'ya': ['2000', 'present']},
#  {'url': '/wiki/Mr._Cheeks',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1971-03-28',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Bounty_Killer',
#   'genre': ['Genre: /wiki/Dancehall'],
#   'born': '1972-06-12',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/I-20_(rapper)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1975-07-08',
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/Freekey_Zekey',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1975-10-13',
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/Birdman_(rapper)',
#   'genre': ['Genre: /wiki/Southern_hip_hop'],
#   'born': '1969-02-15',
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Chingy',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1980-03-09',
#   'ya': ['1997', 'present']},
#  {'url': '/wiki/Frankie_J',
#   'genre': ['Genre: /wiki/Latin_pop'],
#   'born': '1975-12-07',
#   'ya': ['2000', 'present']},
#  {'url': '/wiki/50_Cent',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1975-07-06',
#   'ya': False},
#  {'url': '/wiki/Amanda_Perez',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1980-05-24',
#   'ya': ['2001', 'present']},
#  {'url': '/wiki/Jimmy_Buffett',
#   'genre': ['Genre: #cite_note-8'],
#   'born': '1946-12-25',
#   'ya': ['1964–present']},
#  {'url': '/wiki/Baby_Bash',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1969-10-18',
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/Common_(rapper)',
#   'genre': ['Genre: #cite_note-4'],
#   'born': '1972-03-13',
#   'ya': False},
#  {'url': '/wiki/Floetry',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Norah_Jones',
#   'genre': ['Genre: #cite_note-4'],
#   'born': '1979-03-30',
#   'ya': ['2000', 'present']},
#  {'url': '/wiki/Audioslave',
#   'genre': ['Genre: /wiki/Alternative_rock'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Thal%C3%ADa',
#   'genre': ['Genre: /wiki/Latin_pop'],
#   'born': '1971-08-26',
#   'ya': False},
#  {'url': '/wiki/Field_Mob',
#   'genre': ['Genre: /wiki/Southern_hip_hop'],
#   'born': False,
#   'ya': ['1999', 'present']},
#  {'url': '/wiki/Darryl_Worley',
#   'genre': ['Genre: /wiki/Country_music'],
#   'born': '1964-10-31',
#   'ya': ['1999', 'present']},
#  {'url': '/wiki/Ruben_Studdard',
#   'genre': ['Genre: /wiki/Gospel_music'],
#   'born': '1978-09-12',
#   'ya': ['2003', 'present']},
#  {'url': '/wiki/Dierks_Bentley',
#   'genre': ['Genre: /wiki/Country_music'],
#   'born': '1975-11-20',
#   'ya': ['2001', 'present']},
#  {'url': '/wiki/Young_Gunz',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1999', 'present']},
#  {'url': '/wiki/Mark_Wills',
#   'genre': ['Genre: /wiki/Country_music'],
#   'born': '1973-08-08',
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/Coldplay',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': False,
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/Willie_Nelson',
#   'genre': ['Genre: /wiki/Gospel_music'],
#   'born': '1933-04-29',
#   'ya': False},
#  {'url': '/wiki/Dobie_Gray',
#   'genre': ['Genre: /wiki/Country_music'],
#   'born': '1940-07-26',
#   'ya': ['1960', '2011']},
#  {'url': '/wiki/Black_Eyed_Peas',
#   'genre': ['Genre: #cite_note-IGN-2'],
#   'born': False,
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Murphy_Lee',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': False},
#  {'url': '/wiki/Beyonc%C3%A9',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1981-09-04',
#   'ya': False},
#  {'url': '/wiki/Evanescence',
#   'genre': False,
#   'born': False,
#   'ya': ['1995', 'present (hiatus: 2007', '2009, 2012', '2015)']},
#  {'url': '/wiki/Paul_McCoy',
#   'genre': ['Genre: #cite_note-3'],
#   'born': False,
#   'ya': ['2000', 'present']},
#  {'url': '/wiki/Lil_Jon',
#   'genre': ['Genre: /wiki/Crunk'],
#   'born': '1971-01-17',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/Ying_Yang_Twins',
#   'genre': ['Genre: /wiki/Crunk'],
#   'born': False,
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/YoungBloodZ',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1997', 'present']},
#  {'url': '/wiki/Clay_Aiken',
#   'genre': ['Genre: /wiki/Acoustic_rock'],
#   'born': '1978-11-30',
#   'ya': ['2003', 'present']},
#  {'url': '/wiki/Trapt',
#   'genre': ['Genre: /wiki/Hard_rock'],
#   'born': False,
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Shawnna',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1978-01-03',
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/Jason_Mraz',
#   'genre': ['Genre: #cite_note-4'],
#   'born': '1977-06-23',
#   'ya': False},
#  {'url': '/wiki/Alex_Band',
#   'genre': ['Genre: /wiki/Post-grunge'],
#   'born': '1981-06-08',
#   'ya': ['1999', 'present']},
#  {'url': '/wiki/Jadakiss',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1975-05-27',
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Styles_P',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1974-11-28',
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Charlie_Wilson_(singer)',
#   'genre': ['Genre: /wiki/Gospel_music'],
#   'born': '1953-01-29',
#   'ya': ['1972', 'present']},
#  {'url': '/wiki/Wayne_Wonder',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1972-07-26',
#   'ya': ['1985', 'present']},
#  {'url': '/wiki/St._Lunatics',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1993', 'present']},
#  {'url': '/wiki/Lumidee',
#   'genre': ['Genre: /wiki/Reggaeton'],
#   'born': '1984-10-13',
#   'ya': ['2001', 'present']},
#  {'url': '/wiki/Nick_Cannon',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1980-10-08',
#   'ya': False},
#  {'url': '/wiki/Ryan_Cabrera',
#   'genre': ['Genre: /wiki/Acoustic_music'],
#   'born': '1982-07-18',
#   'ya': ['2001', 'present']},
#  {'url': '/wiki/Jet_(band)',
#   'genre': ['Genre: /wiki/Indie_rock'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Beyonc%C3%A9_Knowles',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1981-09-04',
#   'ya': False},
#  {'url': '/wiki/Finger_Eleven',
#   'genre': ['Genre: #cite_note-4'],
#   'born': False,
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/Lil%27_Flip',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1981-03-03',
#   'ya': ['1999', 'present']},
#  {'url': '/wiki/John_Michael_Montgomery',
#   'genre': ['Genre: /wiki/Country_music'],
#   'born': '1965-01-20',
#   'ya': ['1991', 'present']},
#  {'url': '/wiki/The_Black_Eyed_Peas',
#   'genre': ['Genre: #cite_note-IGN-2'],
#   'born': False,
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Keith_Urban',
#   'genre': ['Genre: #cite_note-allmusic-3'],
#   'born': '1967-10-26',
#   'ya': ['1990', 'present']},
#  {'url': '/wiki/G-Unit',
#   'genre': ['Genre: /wiki/East_Coast_hip_hop'],
#   'born': False,
#   'ya': ['1999', '2018']},
#  {'url': '/wiki/Beenie_Man',
#   'genre': ['Genre: /wiki/Soca_music'],
#   'born': '1973-08-22',
#   'ya': False},
#  {'url': '/wiki/Lloyd_(singer)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1986-01-03',
#   'ya': ['1996', 'present']},
#  {'url': '/wiki/Gretchen_Wilson',
#   'genre': ['Genre: /wiki/Country_rock'],
#   'born': '1973-06-26',
#   'ya': ['2003', 'present']},
#  {'url': '/wiki/Eamon_(singer)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1983-09-19',
#   'ya': ['2003', 'present']},
#  {'url': '/wiki/Kanye_West',
#   'genre': ['Genre: #cite_note-3'],
#   'born': '1977-06-08',
#   'ya': False},
#  {'url': '/wiki/Hoobastank',
#   'genre': ['Genre: /wiki/Ska_punk'],
#   'born': False,
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Sleepy_Brown',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1970-01-24',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Maroon_5',
#   'genre': ['Genre: /wiki/Alternative_rock'],
#   'born': False,
#   'ya': ['1994', 'present']},
#  {'url': '/wiki/Usher_(musician)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1978-10-14',
#   'ya': False},
#  {'url': '/wiki/Jason_Weaver',
#   'genre': False,
#   'born': '1979-07-18',
#   'ya': False},
#  {'url': '/wiki/Kevin_Lyttle',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1976-09-14',
#   'ya': ['2001', 'present']},
#  {'url': '/wiki/Ciara',
#   'genre': ['Genre: /wiki/Dance_music'],
#   'born': '1985-10-25',
#   'ya': False},
#  {'url': '/wiki/Terror_Squad_(group)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': False,
#   'ya': ['1998', '2006']},
#  {'url': '/wiki/Christina_Milian',
#   'genre': ['Genre: /wiki/Dance_music'],
#   'born': '1981-09-26',
#   'ya': False},
#  {'url': '/wiki/Nina_Sky',
#   'genre': ['Genre: /wiki/Dancehall'],
#   'born': False,
#   'ya': ['2003', '–present']},
#  {'url': '/wiki/Petey_Pablo',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1973-07-22',
#   'ya': ['2001', 'present']},
#  {'url': '/wiki/Jamie_Foxx',
#   'genre': ['Genre: /wiki/Satire'],
#   'born': '1967-12-13',
#   'ya': False},
#  {'url': '/wiki/Soulja_Slim',
#   'genre': ['Genre: /wiki/Southern_hip_hop'],
#   'born': '1977-09-09',
#   'ya': ['1993', '2003']},
#  {'url': '/wiki/J-Kwon',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1986-03-28',
#   'ya': ['2003', 'present']},
#  {'url': '/wiki/Remy_Ma',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1980-05-30',
#   'ya': False},
#  {'url': '/wiki/Switchfoot',
#   'genre': ['Genre: /wiki/Pop_rock'],
#   'born': False,
#   'ya': ['1996', 'present (hiatus: 2017', '2018)']},
#  {'url': '/wiki/Houston_(singer)',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1983-10-26',
#   'ya': ['2003-2005']},
#  {'url': '/wiki/Lloyd_Banks',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1982-04-30',
#   'ya': ['1999', 'present']},
#  {'url': '/wiki/D12',
#   'genre': ['Genre: #cite_note-2'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Sasha_(deejay)',
#   'genre': ['Genre: /wiki/Gospel_music'],
#   'born': '1983-10-12',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Syleena_Johnson',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': False,
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Cassidy_(rapper)',
#   'genre': ['Genre: /wiki/East_Coast_hip_hop'],
#   'born': '1982-07-07',
#   'ya': ['1999', 'present']},
#  {'url': '/wiki/Los_Lonely_Boys',
#   'genre': ['Genre: '],
#   'born': False,
#   'ya': ['1996', '2019']},
#  {'url': '/wiki/Ashlee_Simpson',
#   'genre': ['Genre: #cite_note-2'],
#   'born': '1984-10-03',
#   'ya': False},
#  {'url': '/wiki/Kelis',
#   'genre': ['Genre: /wiki/Electronic_music'],
#   'born': '1979-08-21',
#   'ya': False},
#  {'url': '/wiki/Akon',
#   'genre': ['Genre: /wiki/Dancehall'],
#   'born': '1973-04-16',
#   'ya': False},
#  {'url': '/wiki/JoJo_(singer)',
#   'genre': ['Genre: /wiki/Soul_music'],
#   'born': '1990-12-20',
#   'ya': False},
#  {'url': '/wiki/Fantasia_Barrino',
#   'genre': ['Genre: /wiki/Gospel_music'],
#   'born': '1984-06-30',
#   'ya': False},
#  {'url': '/wiki/Pretty_Ricky',
#   'genre': ['Genre: /wiki/Hip_Hop_music'],
#   'born': False,
#   'ya': ['1997', '–present']},
#  {'url': '/wiki/Jesse_McCartney',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1987-04-09',
#   'ya': False},
#  {'url': '/wiki/Mobb_Deep',
#   'genre': ['Genre: #cite_note-2'],
#   'born': False,
#   'ya': ['1991', '2017']},
#  {'url': '/wiki/T.I.',
#   'genre': ['Genre: /wiki/Trap_music_(hip_hop)'],
#   'born': '1980-09-25',
#   'ya': False},
#  {'url': '/wiki/Carrie_Underwood',
#   'genre': ['Genre: /wiki/Country_pop'],
#   'born': '1983-03-10',
#   'ya': False},
#  {'url': '/wiki/Fatman_Scoop',
#   'genre': ['Genre: /wiki/Electronic_dance_music'],
#   'born': '1971-11-28',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Foo_Fighters',
#   'genre': ['Genre: /wiki/Grunge'],
#   'born': False,
#   'ya': ['1994', '–present']},
#  {'url': '/wiki/Amerie',
#   'genre': ['Genre: /wiki/Go-go'],
#   'born': '1980-01-12',
#   'ya': ['2001', 'present']},
#  {'url': '/wiki/Natasha_Bedingfield',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1981-11-26',
#   'ya': ['2001', 'present']},
#  {'url': '/wiki/Natalie_(singer)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1979-09-02',
#   'ya': ['2001-2012, 2020-']},
#  {'url': '/wiki/Bun_B',
#   'genre': ['Genre: /wiki/Southern_hip_hop'],
#   'born': '1973-03-19',
#   'ya': ['1987', 'present']},
#  {'url': '/wiki/Webbie',
#   'genre': ['Genre: /wiki/Southern_hip_hop'],
#   'born': '1985-09-06',
#   'ya': ['2000', 'present']},
#  {'url': '/wiki/Gavin_DeGraw',
#   'genre': ['Genre: /wiki/Rock_music'],
#   'born': '1977-02-04',
#   'ya': ['1998', 'present']},
#  {'url': '/wiki/T-Pain',
#   'genre': ['Genre: /wiki/Contemporary_R%26B'],
#   'born': '1985-09-30',
#   'ya': ['2004', 'present']},
#  {'url': '/wiki/Mike_Jones_(rapper)',
#   'genre': ['Genre: /wiki/Southern_hip_hop'],
#   'born': '1981-11-18',
#   'ya': ['2001', 'present']},
#  {'url': '/wiki/Omarion',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1984-11-12',
#   'ya': ['1998', 'present']},
#  {'url': '/wiki/The_Click_Five',
#   'genre': ['Genre: /wiki/Pop_rock'],
#   'born': False,
#   'ya': ['2004', '2013']},
#  {'url': '/wiki/John_Legend',
#   'genre': ['Genre: /wiki/Pop_music'],
#   'born': '1978-12-28',
#   'ya': False},
#  {'url': '/wiki/Big_Boi',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1975-02-01',
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/Brooke_Valentine',
#   'genre': ['Genre: /wiki/Crunk'],
#   'born': '1984-10-05',
#   'ya': ['2004', 'present']},
#  {'url': '/wiki/Alejandro_Sanz',
#   'genre': ['Genre: /wiki/Soft_rock'],
#   'born': '1968-12-18',
#   'ya': ['1989', 'present']},
#  {'url': '/wiki/Rihanna',
#   'genre': ['Genre: /wiki/Electronic_dance_music'],
#   'born': '1988-02-20',
#   'ya': False},
#  {'url': '/wiki/Game_(rapper)',
#   'genre': ['Genre: /wiki/West_Coast_hip_hop'],
#   'born': '1979-11-29',
#   'ya': ['2002', 'present']},
#  {'url': '/wiki/Weezer',
#   'genre': ['Genre: /wiki/Emo'],
#   'born': False,
#   'ya': ['1992', 'present']},
#  {'url': '/wiki/The_Killers',
#   'genre': ['Genre: /wiki/Synth-pop'],
#   'born': False,
#   'ya': ['2001', 'present']},
#  {'url': '/wiki/Green_Day',
#   'genre': ['Genre: /wiki/Power_pop'],
#   'born': False,
#   'ya': ['1987', 'present']},
#  {'url': '/wiki/Olivia_(singer)',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1980-02-15',
#   'ya': ['2000', 'present']},
#  {'url': '/wiki/The_Pussycat_Dolls',
#   'genre': ['Genre: /wiki/Dance_pop'],
#   'born': False,
#   'ya': []},
#  {'url': '/wiki/Trillville',
#   'genre': ['Genre: /wiki/Ghettotech'],
#   'born': False,
#   'ya': ['1997', 'present']},
#  {'url': '/wiki/David_Banner',
#   'genre': ['Genre: /wiki/Hip_hop_music'],
#   'born': '1974-04-11',
#   'ya': ['1995', 'present']},
#  {'url': '/wiki/Young_Jeezy',
#   'genre': ['Genre: /wiki/Gangsta_rap'],
#   'born': '1977-09-28',
#   'ya': ['1997', 'present']}]

# %%
#Store the list and delete the variable
with open("singer_band_info_list.json","w") as fd:
    json.dump(band_singer_info_list, fd)
del band_singer_info_list

# %%
#Load the list into a variable
with open("singer_band_info_list.json") as json_file:
    band_singer_info_list = json.load(json_file)

# %% [markdown]
# Create a dataframe from the list `singer_band_info_list`.

# %%
#your code here
band_singer_info_df = pd.DataFrame(band_singer_info_list)

# %%
band_singer_info_df.head()
# Out:
#                        url                      genre        born  \
# 0        /wiki/Boyz_II_Men  [Genre: /wiki/Soul_music]       False
# 1     /wiki/Atlantic_Starr  [Genre: /wiki/Soul_music]       False
# 2        /wiki/Celine_Dion   [Genre: /wiki/Soft_rock]  1968-03-30
# 3           /wiki/En_Vogue  [Genre: /wiki/Soul_music]       False
# 4  /wiki/Joe_Public_(band)   [Genre: /wiki/Pop_music]       False
#
#                 ya
# 0   [1987–present]
# 1  [1976, present]
# 2            False
# 3  [1989, present]
# 4  [1989, present]

# %% [markdown]
# ## Q4: Merging Artist's and Song dataframes
# #### [15 points]

# %% [markdown]
# Now, merge the artist/song data frames into one large dataframe. Note that this has an effect of imputing to a song **all the genres** that the artist is active in. We know that this is not true, but it is the simplest assumption we can make, and is probably good for most artists.

# %%
largedf = flatframe.merge(band_singer_info_df, on = 'url', how = "outer")

# %%
len(largedf)
# Out:
# 3873

# %%
largedf.head()
# Out:
#    ranking  band_singer                                      song  \
# 0        1  Boyz II Men                           End of the Road
# 1       37  Boyz II Men  It's So Hard to Say Goodbye to Yesterday
# 2       84  Boyz II Men                                   Uhh Ahh
# 3        1  Boyz II Men                           End of the Road
# 4       37  Boyz II Men  It's So Hard to Say Goodbye to Yesterday
#
#                                             songurl  \
# 0          /wiki/End_of_the_Road_(Boyz_II_Men_song)
# 1  /wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday
# 2                                     /wiki/Uhh_Ahh
# 3          /wiki/End_of_the_Road_(Boyz_II_Men_song)
# 4  /wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday
#
#                                   titletext                url  year   0  \
# 0                           End of the Road  /wiki/Boyz_II_Men  1992   1
# 1  It's So Hard to Say Goodbye to Yesterday  /wiki/Boyz_II_Men  1992  37
# 2                                   Uhh Ahh  /wiki/Boyz_II_Men  1992  84
# 3                           End of the Road  /wiki/Boyz_II_Men  1992   1
# 4  It's So Hard to Say Goodbye to Yesterday  /wiki/Boyz_II_Men  1992  37
#
#                        genre   born              ya
# 0  [Genre: /wiki/Soul_music]  False  [1987–present]
# 1  [Genre: /wiki/Soul_music]  False  [1987–present]
# 2  [Genre: /wiki/Soul_music]  False  [1987–present]
# 3  [Genre: /wiki/Soul_music]  False  [1987–present]
# 4  [Genre: /wiki/Soul_music]  False  [1987–present]

# %% [markdown]
# Update the dataframe by adding a column for each genre with 1-0 encoding for each row. This means, we want columns like "/wiki/Alternative_Rock", "/wiki/Acid_jazz", where if an artist is in that genre, the dataframe cell has a 1. Otherwise, it has a 0.
#
# Remember that an artist/band can be in multiple genres, and must have a 1 for each column corresponding to these genres, and 0 otherwise.
#
# This will widen the dataframe by the total number of genres that we have. The expanded part will look a bit like this:
#
# ![largedfexample](https://drive.google.com/uc?export=view&id=1YgIVsyjWLXIAipI5dF2H4fvAmQodpE8L)

# %% [markdown]
# Ensure the data types of the dataframe is correct

# %%
#Convert to datatypes to required type
largedf['ranking'] = largedf['ranking'].astype('int')
largedf['year'] = largedf['year'].astype('int')
largedf['band_singer'] = largedf['band_singer'].astype('string')
largedf['song'] = largedf['song'].astype('string')
largedf['songurl'] = largedf['songurl'].astype('string')
largedf['titletext '] = largedf['titletext'].astype('string')
largedf['url'] = largedf['url'].astype('string')
largedf['genre'] = largedf['genre'].astype('string')
largedf['born'] = largedf['born'].astype('string')
largedf['ya'] = largedf['ya'].astype('string')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-5496f89b3aff> in <module>
#       7 largedf['titletext '] = largedf['titletext'].astype('string')
#       8 largedf['url'] = largedf['url'].astype('string')
# ----> 9 largedf['genre'] = largedf['genre'].astype('string')
#      10 largedf['born'] = largedf['born'].astype('string')
#      11 largedf['ya'] = largedf['ya'].astype('string')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     819     # dispatch on extension dtype if needed
#     820     if is_extension_array_dtype(dtype):
# --> 821         return dtype.construct_array_type()._from_sequence(arr, dtype=dtype, copy=copy)
#     822
#     823     if not isinstance(dtype, np.dtype):
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\string_.py in _from_sequence(cls, scalars, dtype, copy)
#     195             result[na_values] = StringDtype.na_value
#     196
# --> 197         return cls(result)
#     198
#     199     @classmethod
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\string_.py in __init__(self, values, copy)
#     164         self._dtype = StringDtype()
#     165         if not skip_validation:
# --> 166             self._validate()
#     167
#     168     def _validate(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\string_.py in _validate(self)
#     169         """Validate that we only store NA or strings."""
#     170         if len(self._ndarray) and not lib.is_string_array(self._ndarray, skipna=True):
# --> 171             raise ValueError("StringArray requires a sequence of strings or pandas.NA")
#     172         if self._ndarray.dtype != "object":
#     173             raise ValueError(
#
# ValueError: StringArray requires a sequence of strings or pandas.NA

# %%
largedf.dtypes
# Out:
# ranking         int32
# band_singer    string
# song           string
# songurl        string
# titletext      object
# url            string
# year            int32
# 0              object
# genre          object
# born           object
# ya             object
# titletext      string
# dtype: object

# %%
largedf = largedf[~largedf.genre.isna()]

# %%
largedf = largedf.sort_values('year')

# %%
#One hot encode the data on column genre
largedf1 = pd.get_dummies(largedf.genre, prefix='genre')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     354             try:
# --> 355                 codes, categories = factorize(values, sort=True)
#     356             except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     634
# --> 635         codes, uniques = _factorize_array(
#     636             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     483     table = hash_klass(size_hint or len(values))
# --> 484     uniques, codes = table.factorize(values, na_sentinel=na_sentinel, na_value=na_value)
#     485
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-9edfead6612e> in <module>
#       1 #One hot encode the data on column genre
# ----> 2 largedf1 = pd.get_dummies(largedf.genre, prefix='genre')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     925         result = concat(with_dummies, axis=1)
#     926     else:
# --> 927         result = _get_dummies_1d(
#     928             data,
#     929             prefix,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#     949
#     950     # Series avoids inconsistent NaN handling
# --> 951     codes, levels = factorize_from_iterable(Series(data))
#     952
#     953     if dtype is None:
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in factorize_from_iterable(values)
#    2682         # but only the resulting categories, the order of which is independent
#    2683         # from ordered. Set ordered to False as default. See GH #15457
# -> 2684         cat = Categorical(values, ordered=False)
#    2685         categories = cat.categories
#    2686         codes = cat.codes
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     355                 codes, categories = factorize(values, sort=True)
#     356             except TypeError:
# --> 357                 codes, categories = factorize(values, sort=False)
#     358                 if dtype.ordered:
#     359                     # raise, as we don't have a sortable data structure and so
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     633             na_value = None
#     634
# --> 635         codes, uniques = _factorize_array(
#     636             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     637         )
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     482
#     483     table = hash_klass(size_hint or len(values))
# --> 484     uniques, codes = table.factorize(values, na_sentinel=na_sentinel, na_value=na_value)
#     485
#     486     codes = ensure_platform_int(codes)
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
largedf1.head()
# Out:
#      genre_/wiki/%2703_Bonnie_%26_Clyde  genre_/wiki/%27Til_You_Do_Me_Right  \
# 0                                     0                                   0
# 214                                   0                                   0
# 215                                   0                                   0
# 216                                   0                                   0
# 217                                   0                                   0
#
#      genre_/wiki/(At_Your_Best)_You_Are_Love#Aaliyah_version  \
# 0                                                    0
# 214                                                  0
# 215                                                  0
# 216                                                  0
# 217                                                  0
#
#      genre_/wiki/(God_Must_Have_Spent)_A_Little_More_Time_on_You  \
# 0                                                    0
# 214                                                  0
# 215                                                  0
# 216                                                  0
# 217                                                  0
#
#      genre_/wiki/(God_Must_Have_Spent)_A_Little_More_Time_on_You#Alabama_version  \
# 0                                                    0
# 214                                                  0
# 215                                                  0
# 216                                                  0
# 217                                                  0
#
#      genre_/wiki/(When_You_Gonna)_Give_It_Up_to_Me  \
# 0                                                0
# 214                                              0
# 215                                              0
# 216                                              0
# 217                                              0
#
#      genre_/wiki/...Baby_One_More_Time_(song)  \
# 0                                           0
# 214                                         0
# 215                                         0
# 216                                         0
# 217                                         0
#
#      genre_/wiki/0_to_100_/_The_Catch_Up  \
# 0                                      0
# 214                                    0
# 215                                    0
# 216                                    0
# 217                                    0
#
#      genre_/wiki/1,_2,_3,_4_(Sumpin%27_New)  genre_/wiki/1,_2_Step  ...  \
# 0                                         0                      0  ...
# 214                                       0                      0  ...
# 215                                       0                      0  ...
# 216                                       0                      0  ...
# 217                                       0                      0  ...
#
#      genre_/wiki/Young_Dumb_%26_Broke  genre_/wiki/Young_Forever  \
# 0                                   0                          0
# 214                                 0                          0
# 215                                 0                          0
# 216                                 0                          0
# 217                                 0                          0
#
#      genre_/wiki/Youngblood_(5_Seconds_of_Summer_song)  \
# 0                                                    0
# 214                                                  0
# 215                                                  0
# 216                                                  0
# 217                                                  0
#
#      genre_/wiki/Your_Body%27s_Callin%27  \
# 0                                      0
# 214                                    0
# 215                                    0
# 216                                    0
# 217                                    0
#
#      genre_/wiki/Your_Body_(Pretty_Ricky_song)  \
# 0                                            0
# 214                                          0
# 215                                          0
# 216                                          0
# 217                                          0
#
#      genre_/wiki/Your_Body_Is_a_Wonderland  \
# 0                                        0
# 214                                      0
# 215                                      0
# 216                                      0
# 217                                      0
#
#      genre_/wiki/Your_Love_(Nicki_Minaj_song)  \
# 0                                           0
# 214                                         0
# 215                                         0
# 216                                         0
# 217                                         0
#
#      genre_/wiki/Your_Love_Is_My_Drug  genre_/wiki/Your_Woman  \
# 0                                   0                       0
# 214                                 0                       0
# 215                                 0                       0
# 216                                 0                       0
# 217                                 0                       0
#
#      genre_/wiki/Zeze_(song)
# 0                          0
# 214                        0
# 215                        0
# 216                        0
# 217                        0
#
# [5 rows x 2543 columns]

# %%
#Store the dataframe to use in HW-2 
largedf.to_pickle('largedf')
del largedf

# %%
#Loading in dataframe
largedf = pd.read_pickle('largedf')
largedf.head()
# Out:
#      ranking   band_singer                              song  \
# 0          1   Boyz II Men                   End of the Road
# 291       92  Richard Marx                  Keep Coming Back
# 290       81  Richard Marx                   Take This Heart
# 299       59   The Heights       How Do You Talk to an Angel
# 153       22   Patty Smyth  Sometimes Love Just Ain't Enough
#
#                                       songurl  \
# 0    /wiki/End_of_the_Road_(Boyz_II_Men_song)
# 291             /wiki/Keep_Coming_Back_(song)
# 290                     /wiki/Take_This_Heart
# 299         /wiki/How_Do_You_Talk_to_an_Angel
# 153  /wiki/Sometimes_Love_Just_Ain%27t_Enough
#
#                             titletext                                     url  \
# 0                     End of the Road                       /wiki/Boyz_II_Men
# 291                  Keep Coming Back                      /wiki/Richard_Marx
# 290                   Take This Heart                      /wiki/Richard_Marx
# 299       How Do You Talk to an Angel  /wiki/The_Heights_(American_TV_series)
# 153  Sometimes Love Just Ain't Enough                       /wiki/Patty_Smyth
#
#      year   0                            genre        born  \
# 0    1992   1      ['Genre: /wiki/Soul_music']       False
# 291  1992  92          ['Genre: #cite_note-3']  1963-09-16
# 290  1992  81          ['Genre: #cite_note-3']  1963-09-16
# 299  1992  59                            False       False
# 153  1992  22  ['Genre: /wiki/New_wave_music']  1957-06-26
#
#                       ya                        titletext
# 0       ['1987–present']                   End of the Road
# 291  ['1980', 'present']                  Keep Coming Back
# 290  ['1980', 'present']                   Take This Heart
# 299                False       How Do You Talk to an Angel
# 153  ['1981', 'present']  Sometimes Love Just Ain't Enough

# %% [markdown]
# ## Q5: Pandas and Relational databases
# #### [20 points]

# %% [markdown]
# ### 5.1 Populating the database

# %% [markdown]
# We use sqlite3 here. There is an even higher level API available, called SQLAlchemy.  However SQLite is built into Python and also has a command line tool and sqlite browser that you can install.

# %%
import sqlite3 as sql

# %% [markdown]
# Let us start by creating our schema to set the type of each column in our dataframe.

# %%
ourschema = """
DROP TABLE IF EXISTS "BillboardHot100Singles";
CREATE TABLE "BillboardHot100Singles" (
    "id" INTEGER PRIMARY KEY  NOT NULL ,
    "ranking" INTEGER NOT NULL ,
    "band_singer" VARCHAR,
    "song" VARCHAR,
    "songurl" VARCHAR,
    "titletext" VARCHAR,
    "url" VARCHAR,
    "year" Integer,
    "0" VARCHAR,
    "genre" VARCHAR,
    "born" VARCHAR,
    "ya" VARCHAR
);
"""

# %% [markdown]
# Next, create a connection object which will connect us to the database and will let us execute the SQL statements.
# Create an object of the cursor using the connection object and execute our schema.
# Finally, use the `to_sql` function and convert our large expanded dataframe from the last section to a table.

# %%
from sqlite3 import dbapi2 as sq3
from pathlib import Path
PATHSTART="."
def get_db(dbfile):
    sqlite_db = sq3.connect(Path(PATHSTART) / dbfile)
    return sqlite_db

# %%
def init_db(dbfile, schema):
    db = get_db(dbfile) 
    db.cursor().executescript(schema)
    db.commit()
    return db

# %%
db=init_db("hotsingles.db", ourschema)

# %%
#Converts into a SQL Database
largedf.to_sql("BillboardHot100Singles", db, if_exists="append", index=False)

# %% [markdown]
# ### 5.2 Performing operations on the database

# %%
#Defining a function to make a query
def make_query(sel):
    c=db.cursor().execute(sel)
    return c.fetchall()

# %%
from collections import OrderedDict
def make_frame(list_of_tuples, legend):
    framelist=[]
    for i, cname in enumerate(legend):
        framelist.append((cname,[e[i] for e in list_of_tuples]))
    return pd.DataFrame.from_dict(OrderedDict(framelist))

# %%
#Checking the columns of BillboardHot100Singles table
cols = [e[1] for e in make_query("PRAGMA table_info(BillboardHot100Singles);")]
cols
# Out:
# ['ranking',
#  'band_singer',
#  'song',
#  'songurl',
#  'titletext',
#  'url',
#  'year',
#  '0',
#  'genre',
#  'born',
#  'ya',
#  'titletext ']

# %%
out=make_query("SELECT * FROM BillboardHot100Singles;")
#Create a dataframe
make_frame(out, legend=cols)
# Out:
#       ranking      band_singer                              song  \
# 0           1      Boyz II Men                   End of the Road
# 1          92     Richard Marx                  Keep Coming Back
# 2          81     Richard Marx                   Take This Heart
# 3          59      The Heights       How Do You Talk to an Angel
# 4          22      Patty Smyth  Sometimes Love Just Ain't Enough
# ...       ...              ...                               ...
# 3868       13            Lizzo                       Truth Hurts
# 3869       49        Sheck Wes                          Mo Bamba
# 3870       19   Bradley Cooper                           Shallow
# 3871        1  Billy Ray Cyrus                     Old Town Road
# 3872       58            Diplo                       Close to Me
#
#                                                 songurl  \
# 0              /wiki/End_of_the_Road_(Boyz_II_Men_song)
# 1                         /wiki/Keep_Coming_Back_(song)
# 2                                 /wiki/Take_This_Heart
# 3                     /wiki/How_Do_You_Talk_to_an_Angel
# 4              /wiki/Sometimes_Love_Just_Ain%27t_Enough
# ...                                                 ...
# 3868                           /wiki/Truth_Hurts_(song)
# 3869                              /wiki/Mo_Bamba_(song)
# 3870  /wiki/Shallow_(Lady_Gaga_and_Bradley_Cooper_song)
# 3871                                /wiki/Old_Town_Road
# 3872  /wiki/Close_to_Me_(Ellie_Goulding,_Diplo_and_S...
#
#                              titletext  \
# 0                      End of the Road
# 1                     Keep Coming Back
# 2                      Take This Heart
# 3          How Do You Talk to an Angel
# 4     Sometimes Love Just Ain't Enough
# ...                                ...
# 3868                       Truth Hurts
# 3869                          Mo Bamba
# 3870                           Shallow
# 3871                     Old Town Road
# 3872                       Close to Me
#
#                                          url  year   0  \
# 0                          /wiki/Boyz_II_Men  1992   1
# 1                         /wiki/Richard_Marx  1992  92
# 2                         /wiki/Richard_Marx  1992  81
# 3     /wiki/The_Heights_(American_TV_series)  1992  59
# 4                          /wiki/Patty_Smyth  1992  22
# ...                                      ...   ...  ..
# 3868                             /wiki/Lizzo  2019  13
# 3869                         /wiki/Sheck_Wes  2019  49
# 3870                    /wiki/Bradley_Cooper  2019  19
# 3871                   /wiki/Billy_Ray_Cyrus  2019   1
# 3872                             /wiki/Diplo  2019  58
#
#                                 genre        born                   ya  \
# 0         ['Genre: /wiki/Soul_music']       False     ['1987–present']
# 1             ['Genre: #cite_note-3']  1963-09-16  ['1980', 'present']
# 2             ['Genre: #cite_note-3']  1963-09-16  ['1980', 'present']
# 3                               False       False                False
# 4     ['Genre: /wiki/New_wave_music']  1957-06-26  ['1981', 'present']
# ...                               ...         ...                  ...
# 3868         ['Genre: /wiki/Doo-wop']  1988-04-27                False
# 3869      ['Genre: /wiki/Trap_music']  1998-09-10  ['2018', 'present']
# 3870                            False  1975-01-05                False
# 3871   ['Genre: /wiki/Country_music']  1961-08-25                False
# 3872      ['Genre: /wiki/Moombahton']  1978-11-10                False
#
#                             titletext
# 0                      End of the Road
# 1                     Keep Coming Back
# 2                      Take This Heart
# 3          How Do You Talk to an Angel
# 4     Sometimes Love Just Ain't Enough
# ...                                ...
# 3868                       Truth Hurts
# 3869                          Mo Bamba
# 3870                           Shallow
# 3871                     Old Town Road
# 3872                       Close to Me
#
# [3873 rows x 12 columns]

# %% [markdown]
# Answer the following questions by writing SQL statements.

# %% [markdown]
# #### 5.2.1 Select all singers below the age of 20 whos Zodiac Sign is Scorpio!

# %%
#your code here
#your code here
out=make_query("SELECT * FROM BillboardHot100Singles where age < 20 and Zodiac_Sign = 'Scorpio'")
#Create a dataframe
make_frame(out, legend=cols)

# %% [markdown]
# #### 5.2.2 Find the most popular artists with most appearances in Billboard Top 10

# %%
cols_bs = ["band_singer", "count"]

# %%
#your code here
out=make_query("SELECT band_singer, count(*) as count FROM BillboardHot100Singles group by band_singer order by count desc")
#Create a dataframe
make_frame(out, legend=cols_bs)
# Out:
#          band_singer  count
# 0              Drake     51
# 1            Rihanna     46
# 2          Lil Wayne     35
# 3              Usher     31
# 4       Mariah Carey     31
# ...              ...    ...
# 1227             3LW      1
# 1228      20 Fingers      1
# 1229       2 Pistols      1
# 1230  10,000 Maniacs      1
# 1231            None      1
#
# [1232 rows x 2 columns]

# %% [markdown]
# #### 5.2.3 Select all songs with ranking less than 6 and order the rows by artist name

# %%
out=make_query("SELECT * FROM BillboardHot100Singles where ranking < 6 order by band_singer")
#Create a dataframe
make_frame(out, legend=cols)
# Out:
#      ranking   band_singer                             song  \
# 0          3           112              I'll Be Missing You
# 1          5     21 Savage                         Rockstar
# 2          5  3 Doors Down                    When I'm Gone
# 3          1       50 Cent                       In da Club
# 4          1   Ace of Base                         The Sign
# ..       ...           ...                              ...
# 198        3        Wizkid                        One Dance
# 199        5   Wyclef Jean                   Hips Don't Lie
# 200        4    Young Thug                           Havana
# 201        5      Yung Joc  Buy U a Drank (Shawty Snappin')
# 202        5     will.i.am                              OMG
#
#                                        songurl  \
# 0                  /wiki/I%27ll_Be_Missing_You
# 1            /wiki/Rockstar_(Post_Malone_song)
# 2    /wiki/When_I%27m_Gone_(3_Doors_Down_song)
# 3                             /wiki/In_da_Club
# 4                        /wiki/The_Sign_(song)
# ..                                         ...
# 198                            /wiki/One_Dance
# 199                     /wiki/Hips_Don%27t_Lie
# 200         /wiki/Havana_(Camila_Cabello_song)
# 201    /wiki/Buy_U_a_Drank_(Shawty_Snappin%27)
# 202                     /wiki/OMG_(Usher_song)
#
#                            titletext                      url  year  0  \
# 0                I'll Be Missing You         /wiki/112_(band)  1997  3
# 1                           Rockstar          /wiki/21_Savage  2018  5
# 2                      When I'm Gone       /wiki/3_Doors_Down  2003  5
# 3                         In da Club            /wiki/50_Cent  2003  1
# 4                           The Sign        /wiki/Ace_of_Base  1994  1
# ..                               ...                      ...   ... ..
# 198                        One Dance  /wiki/Wizkid_(musician)  2016  3
# 199                   Hips Don't Lie        /wiki/Wyclef_Jean  2006  5
# 200                           Havana         /wiki/Young_Thug  2018  4
# 201  Buy U a Drank (Shawty Snappin')           /wiki/Yung_Joc  2007  5
# 202                              OMG          /wiki/Will.i.am  2010  5
#
#                                        genre        born                   ya  \
# 0        ['Genre: /wiki/Contemporary_R%26B']       False     ['1993–present']
# 1                    ['Genre: #cite_note-2']  1992-10-22  ['2013', 'present']
# 2           ['Genre: #cite_note-usatoday-3']       False  ['1996', 'present']
# 3             ['Genre: /wiki/Hip_hop_music']  1975-07-06                False
# 4            ['Genre: #cite_note-Europop-5']       False  ['1990', 'present']
# ..                                       ...         ...                  ...
# 198  ['Genre: #cite_note-RCA_Records_Bio-1']  1990-07-16     ['2001–present']
# 199                ['Genre: /wiki/Neo_soul']  1969-10-17                False
# 200                 ['Genre: /wiki/Pop_rap']  1991-08-16     ['2010–present']
# 201           ['Genre: /wiki/Hip_hop_music']  1980-09-20  ['2003', 'present']
# 202      ['Genre: /wiki/Contemporary_R%26B']  1975-03-15     ['1988–present']
#
#                           titletext
# 0                I'll Be Missing You
# 1                           Rockstar
# 2                      When I'm Gone
# 3                         In da Club
# 4                           The Sign
# ..                               ...
# 198                        One Dance
# 199                   Hips Don't Lie
# 200                           Havana
# 201  Buy U a Drank (Shawty Snappin')
# 202                              OMG
#
# [203 rows x 12 columns]
